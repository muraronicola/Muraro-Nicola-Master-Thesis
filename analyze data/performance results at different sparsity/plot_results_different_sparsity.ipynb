# %%
import numpy as numpy
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scienceplots
import copy


base_path = "./data/processed_data/"
path_counter = base_path + "counter/"
path_mean_std = base_path + "mean_std/"

base_plot_path = "./plots/"

base_name = "results_{}__{}_{}.pt"

dataset_list = ['c4', 'oscar', 'redpajama', 'wikitext2', 'pile', 'gsm8k', 'svamp', 'mawps', 'anli_r1', 'esnli', 'rte', 'boolq', 'commonsense_qa', 'race',
                'winogrande', 'wmt14', 'iwslt', 'opc', 'ds1000', 'mbpp']


model_list = ['meta-llama/Llama-2-7b-hf', 'mistralai/Mistral-7B-v0.1', 'microsoft/phi-2', 'baichuan-inc/Baichuan-7B', 'Qwen/Qwen2.5-7B' ]
models_names_print = ['Llama', 'Phi', 'Mistral', 'Baichuan', 'Qwen']
model_name = models_names_print #[name.split('/')[1] for name in model_list] #, 'Llama-3.2-1B']
rename_dictionary_model_names = {model_list[i]: models_names_print[i] for i in range(len(model_list))}

sparsity_list = [0.1, 0.3, 0.5, 0.7, 0.9]

dataset_list_print = ['C4', 'OSCAR', 'RedPajama', 'WikiText', 'Pile', 'GSM8K', 'SVAMP', 'MAWPS', 'ANLI', 'e-SNLI', 'RTE', 'BoolQ', 'CommonsenseQA', 'RACE', 'WinoGrande', 'WMT14', 'IWSLT', 'RefineCode', 'DS1000', 'MBPP']
rename_dictionary_dataset = {dataset_list[i]: dataset_list_print[i] for i in range(len(dataset_list))}

plt.style.use('science')

# %%
#Create a custom color palette for the plot

original_cmap = sns.color_palette("Spectral_r", as_cmap=True) 
colors = np.concatenate((original_cmap(np.linspace(0, 0.35, 4)), original_cmap(np.linspace(0.6, 1, 4))), axis=0) # Extract 10 colors
custom_palette = np.clip(colors, 0, 1) # Ensure valid RGB range
custom_palette = [tuple(c) for c in custom_palette]  # Convert array to list of 


palette_heatmap =  sns.color_palette("Blues", as_cmap=True) 
colors_blues = np.concatenate((palette_heatmap(np.linspace(0, 0.35, 1)), palette_heatmap(np.linspace(0.8, 1, 10))), axis=0) # Extract 10 colors
custom_blues = np.clip(colors_blues, 0, 1) # Ensure valid RGB range
custom_blues = [tuple(c) for c in custom_blues]  # Convert array to list of 

one_color = sns.color_palette("mako", as_cmap=True).colors[190]

# %%
#results = pd.read_csv("./only_completed.csv") # results.csv
#results = pd.read_csv("./only_completed_v2.csv") # results.csv
#results = pd.read_csv("./only_mistral_qwen.csv") # results.csv
results = pd.read_csv("./results.csv") # results.csv

metric_map = {
    'c4': 'ppl',
    'oscar': 'ppl',
    'redpajama': 'ppl',
    'wikitext2': 'ppl',
    'pile': 'ppl',
    'gsm8k': 'acc',
    'svamp': 'acc',
    'mawps': 'acc',
    'anli_r1': 'acc',
    'esnli': 'acc',
    'rte': 'acc',
    'boolq': 'acc',
    'commonsense_qa': 'acc',
    'race': 'acc',
    'winogrande': 'acc',
    'wmt14': 'bleu',
    'iwslt': 'bleu',
    'opc': 'f1',
    'ds1000': 'f1',
    'mbpp': 'f1',
}

task_map = {
    'none': 'Dense',
    'c4': 'Language Modeling',
    'oscar': 'Language Modeling',
    'redpajama': 'Language Modeling',
    'wikitext2': 'Language Modeling',
    'pile': 'Language Modeling',
    'gsm8k': 'Mathematical Reasoning',
    'svamp': 'Mathematical Reasoning',
    'mawps': 'Mathematical Reasoning',
    'anli_r1': 'NLI',
    'esnli': 'NLI',
    'rte': 'NLI',
    'boolq': 'Question Answering',
    'commonsense_qa': 'Question Answering',
    'race': 'Question Answering',
    'winogrande': 'Question Answering',
    'wmt14': 'Translation',
    'iwslt': 'Translation',
    'opc': 'Coding',
    'ds1000': 'Coding',
    'mbpp': 'Coding',
}

results["dataset_group"] = results["dataset"].map(task_map)
results["pruning_group"] = results["pruning_data"].map(task_map)

order_columns = ['Dense', 'C4', 'OSCAR', 'Pile', 'RedPajama', 'WikiText', 'ANLI', 'BoolQ', 'CommonsenseQA', 'e-SNLI', 'GSM8K', 'MAWPS', 'RACE',  'RTE',   'SVAMP',  'WinoGrande', 'IWSLT',  'WMT14', 'DS1000', 'MBPP', 'RefineCode']
order_columns_grouped = ['Dense', 'Language Modeling', 'Mathematical Reasoning', 'NLI', 'Question Answering', 'Translation', 'Coding']

headers = {
    'selector': 'th.col_heading',
    'props': 'background-color: #5E17EB; color: white;'
}

index_style = {
    'selector': 'th.index_name',
    'props': 'background-color: #5E17EB; color: white;'
}

#none is the dense model
results['pruning_data'] = results['pruning_data'].replace({'none': 'dense'})

results['metric'] = results['dataset'].map(metric_map)
print(results['metric'].unique())

print(results['dataset'].unique())

results['value'] = results.apply(lambda row: row[row['metric']], axis=1)
precision = 3
results['value'] = results['value'].round(precision)


results['model'] = results['model'].replace(rename_dictionary_model_names)
results['dataset'] = results['dataset'].replace(rename_dictionary_dataset)
results['dataset'] = results['dataset'].replace({'dense': 'Dense'})

results['pruning_data'] = results['pruning_data'].replace(rename_dictionary_dataset)
results['pruning_data'] = results['pruning_data'].replace({'dense': 'Dense'})
# Out:
# ['acc' 'ppl' 'f1' 'bleu']
# ['anli_r1' 'boolq' 'c4' 'commonsense_qa' 'ds1000' 'esnli' 'gsm8k' 'iwslt'
#  'mawps' 'mbpp' 'opc' 'oscar' 'pile' 'race' 'redpajama' 'rte' 'svamp'
#  'wikitext2' 'winogrande' 'wmt14']

# %%
"""#Group bymodel, sparsity, pruning_data, datset -> if there are multiple values for the same pruning_data and dataset, return an error

print(len(results))
grouped = results.groupby(['model', 'sparsity', 'pruning_data', 'dataset']).aggregate({'acc': 'first', 'bleu': 'first', 'ppl': 'first', 'f1': 'first'}).reset_index()
print(grouped)

#'DataFrameGroupBy' object has no attribute 'to_csv'

grouped.to_csv('unique_results.csv', index=False)"""
# Out:
# "#Group bymodel, sparsity, pruning_data, datset -> if there are multiple values for the same pruning_data and dataset, return an error\n\nprint(len(results))\ngrouped = results.groupby(['model', 'sparsity', 'pruning_data', 'dataset']).aggregate({'acc': 'first', 'bleu': 'first', 'ppl': 'first', 'f1': 'first'}).reset_index()\nprint(grouped)\n\n#'DataFrameGroupBy' object has no attribute 'to_csv'\n\ngrouped.to_csv('unique_results.csv', index=False)"

# %%
def generate_table(data, metric, highlight_min=False, order_columns=order_columns):
    data_metric = data[data['metric'] == metric]
    
    pivot_table = (
        pd.pivot_table(data = data_metric.round(precision),
            columns='pruning_data',
            index='dataset',
            values='value'
            ).reindex(order_columns, axis=1)
    )
    
    #print(pivot_table.style.format(precision=3).to_latex())
    
    if highlight_min:
        pivot_style = (
            pivot_table
                .style
                    .set_table_styles([headers,index_style])
                    .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
                    .highlight_min(order_columns[1:], axis=1, color="yellow")
                    .highlight_min(axis=1, color="red")
                    .format(precision=precision)
        )
    else:
        pivot_style = (
            pivot_table
                .style
                    .set_table_styles([headers,index_style])
                    .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
                    .highlight_max(order_columns[1:], axis=1, color="yellow")
                    .highlight_max(axis=1, color="red")
                    .format(precision=precision)
        )
    
    return pivot_style

# %%
"""for i in range(len(model_list)):
    
    for sparsity in [0.9]: #sparsity_list:
        data_model = results[(results['model'] == model_list[i]) & ((results['sparsity'] == sparsity) | (results['sparsity'] == 0.0))]

        tmp_pivot_style_ppl = generate_table(data_model, 'ppl', highlight_min=True)
        tmp_pivot_style_acc = generate_table(data_model, 'acc')
        tmp_pivot_style_bleu = generate_table(data_model, 'bleu')
        tmp_pivot_style_f1 = generate_table(data_model, 'f1')

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", PPL")
        display(tmp_pivot_style_ppl)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", ACC")
        display(tmp_pivot_style_acc)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", BLEU")
        display(tmp_pivot_style_bleu)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", F1")
        display(tmp_pivot_style_f1)
        
        print("--------------------\n\n\n\n\n")
    
"""
# Out:
# 'for i in range(len(model_list)):\n    \n    for sparsity in [0.9]: #sparsity_list:\n        data_model = results[(results[\'model\'] == model_list[i]) & ((results[\'sparsity\'] == sparsity) | (results[\'sparsity\'] == 0.0))]\n\n        tmp_pivot_style_ppl = generate_table(data_model, \'ppl\', highlight_min=True)\n        tmp_pivot_style_acc = generate_table(data_model, \'acc\')\n        tmp_pivot_style_bleu = generate_table(data_model, \'bleu\')\n        tmp_pivot_style_f1 = generate_table(data_model, \'f1\')\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", PPL")\n        display(tmp_pivot_style_ppl)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", ACC")\n        display(tmp_pivot_style_acc)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", BLEU")\n        display(tmp_pivot_style_bleu)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", F1")\n        display(tmp_pivot_style_f1)\n        \n        print("--------------------\n\n\n\n\n")\n    \n'

# %% [markdown]
# <h1>Percentage results</h1>

# %%
def get_percentage_values(data, metric):
    
    list_this__dataset = data['dataset'].unique()
    analyze_dataset = []
    for datasetname in list_this__dataset: #Voglio solo i dataset, non anche le medie tra i vari datset (all, all_prototype, ...)
        if datasetname in dataset_list_print:
            analyze_dataset.append(datasetname)
    
    for group_value in analyze_dataset: #analyze_dataset:
        group_mask = data['dataset'] == group_value
        dense_mask = group_mask & (data['pruning_data'] == 'Dense')

        # Estrai valore di riferimento
        ref_rows = data.loc[dense_mask, metric]

        if not ref_rows.empty:
            ref_value = ref_rows.iloc[0]
            # Assegna i valori normalizzati direttamente tramite .loc (modo sicuro)
            if metric == "ppl":
                data.loc[group_mask, 'percentage'] = ref_value / data.loc[group_mask, metric]
            else:
                data.loc[group_mask, 'percentage'] = data.loc[group_mask, metric] / ref_value
        else:
            print(f"Nessuna riga 'dense' per a3 == {group_value}")
            
    return data

def generate_table_percentage(data, metric, order_columns=order_columns):
    data_metric = data[data['metric'] == metric]
    data_metric = get_percentage_values(data_metric, metric)
    
    pivot_table = (
        pd.pivot_table(data = data_metric.round(precision),
            columns='pruning_data',
            index='dataset',
            values='percentage'
            ).reindex(order_columns, axis=1)
    )
    
    #print(pivot_table.style.format(precision=3).to_latex())
    
    pivot_style = (
        pivot_table
            .style
                .set_table_styles([headers,index_style])
                .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
                .highlight_max(order_columns[1:], axis=1, color="yellow")
                .highlight_max(axis=1, color="red")
                .format(precision=precision)
    )
    
    return pivot_style

def get_table(data):
    pivot_table = (
        pd.pivot_table(data = data,
            columns='pruning_data',
            index='dataset',
            values='percentage'
            ).reindex(order_columns, axis=1)
    )
    
    pivot_style = (
        pivot_table
            .style
                .set_table_styles([headers,index_style])
                .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
                .highlight_max(order_columns[1:], axis=1, color="yellow")
                .highlight_max(axis=1, color="red")
                .format(precision=precision)
    )
    
    return pivot_style


"""
for i in range(len(model_list)):
    
    for sparsity in sparsity_list:
        data_model = results[(results['model'] == model_list[i]) & ((results['sparsity'] == sparsity) | (results['sparsity'] == 0.0))]

        data_model['percentage'] = pd.NA
        
        tmp_pivot_style_ppl = generate_table_percentage(data_model, 'ppl')
        tmp_pivot_style_acc = generate_table_percentage(data_model, 'acc')
        tmp_pivot_style_bleu = generate_table_percentage(data_model, 'bleu')
        tmp_pivot_style_f1 = generate_table_percentage(data_model, 'f1')

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", PPL")
        display(tmp_pivot_style_ppl)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", ACC")
        display(tmp_pivot_style_acc)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", BLEU")
        display(tmp_pivot_style_bleu)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", F1")
        display(tmp_pivot_style_f1)
        
        print("--------------------\n\n\n\n\n")
"""
# Out:
# '\nfor i in range(len(model_list)):\n    \n    for sparsity in sparsity_list:\n        data_model = results[(results[\'model\'] == model_list[i]) & ((results[\'sparsity\'] == sparsity) | (results[\'sparsity\'] == 0.0))]\n\n        data_model[\'percentage\'] = pd.NA\n        \n        tmp_pivot_style_ppl = generate_table_percentage(data_model, \'ppl\')\n        tmp_pivot_style_acc = generate_table_percentage(data_model, \'acc\')\n        tmp_pivot_style_bleu = generate_table_percentage(data_model, \'bleu\')\n        tmp_pivot_style_f1 = generate_table_percentage(data_model, \'f1\')\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", PPL")\n        display(tmp_pivot_style_ppl)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", ACC")\n        display(tmp_pivot_style_acc)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", BLEU")\n        display(tmp_pivot_style_bleu)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", F1")\n        display(tmp_pivot_style_f1)\n        \n        print("--------------------\n\n\n\n\n")\n'

# %% [markdown]
# <h1>Drop in task performance</h1>

# %%
def generate_table_percentage_task(data, metric, order_columns_grouped=order_columns_grouped):
    data_metric = data[data['metric'] == metric]
    data_metric = get_percentage_values(data_metric, metric)
    data_metric = data_metric.groupby(['dataset_group', 'pruning_group']).agg(percentage_group=('percentage', 'mean'))
    
    pivot_table = (
        pd.pivot_table(data = data_metric.round(precision),
            columns='pruning_group',
            index='dataset_group',
            values='percentage_group'
            ).reindex(order_columns_grouped, axis=1)
    )
    
    pivot_style = (
        pivot_table
            .style
                .set_table_styles([headers,index_style])
                .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
                .highlight_max(order_columns_grouped[1:], axis=1, color="yellow")
                .highlight_max(axis=1, color="red")
                .format(precision=precision)
    )
    
    return pivot_style


def get_table_task(data):
    pivot_table = (
        pd.pivot_table(data = data,
            columns='pruning_group',
            index='dataset_group',
            values='percentage_group'
            ).reindex(order_columns_grouped, axis=1)
    )
    
    pivot_style = (
        pivot_table
            .style
                .set_table_styles([headers,index_style])
                .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
                .highlight_max(order_columns_grouped[1:], axis=1, color="yellow")
                .highlight_max(axis=1, color="red")
                .format(precision=precision)
    )
    
    return pivot_style

"""
for i in range(len(model_list)):
    for sparsity in sparsity_list:
        data_model = results[(results['model'] == model_list[i]) & ((results['sparsity'] == sparsity) | (results['sparsity'] == 0.0))]
        data_model['percentage'] = pd.NA
        
        
        tmp_pivot_style_ppl = generate_table_percentage_task(data_model, 'ppl')
        tmp_pivot_style_acc = generate_table_percentage_task(data_model, 'acc')
        tmp_pivot_style_bleu = generate_table_percentage_task(data_model, 'bleu')
        tmp_pivot_style_f1 = generate_table_percentage_task(data_model, 'f1')

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", PPL")
        display(tmp_pivot_style_ppl)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", ACC")
        display(tmp_pivot_style_acc)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", BLEU")
        display(tmp_pivot_style_bleu)

        print(model_name[i] + ", sparsity: " + str(sparsity) + ", F1")
        display(tmp_pivot_style_f1)
        
        
        print("--------------------\n\n\n\n\n")
        
"""
# Out:
# '\nfor i in range(len(model_list)):\n    for sparsity in sparsity_list:\n        data_model = results[(results[\'model\'] == model_list[i]) & ((results[\'sparsity\'] == sparsity) | (results[\'sparsity\'] == 0.0))]\n        data_model[\'percentage\'] = pd.NA\n        \n        \n        tmp_pivot_style_ppl = generate_table_percentage_task(data_model, \'ppl\')\n        tmp_pivot_style_acc = generate_table_percentage_task(data_model, \'acc\')\n        tmp_pivot_style_bleu = generate_table_percentage_task(data_model, \'bleu\')\n        tmp_pivot_style_f1 = generate_table_percentage_task(data_model, \'f1\')\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", PPL")\n        display(tmp_pivot_style_ppl)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", ACC")\n        display(tmp_pivot_style_acc)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", BLEU")\n        display(tmp_pivot_style_bleu)\n\n        print(model_name[i] + ", sparsity: " + str(sparsity) + ", F1")\n        display(tmp_pivot_style_f1)\n        \n        \n        print("--------------------\n\n\n\n\n")\n        \n'

# %% [markdown]
# <h1>AVG over models</h1>

# %%
data_avg = results.copy()

#da data togli il valore di baichuan-7b in evaluation of boolq


data_avg = data_avg[~((data_avg['model'] == 'Baichuan') & (data_avg['dataset'] == 'BoolQ'))]
data_avg = data_avg[~((data_avg['model'] == 'Qwen') & (data_avg['dataset'] == 'RACE'))]



data_avg = data_avg[data_avg['dataset'] != 'GSM8K'] #Attualmente non ha valori sensati

#data_avg = results
data_avg['percentage'] = pd.NA

# %%
"""
for sparsity in sparsity_list:
    data_avg_sparsity = data_avg[(data_avg['sparsity'] == sparsity) | (data_avg['sparsity'] == 0.0)]
    tmp_pivot_style_ppl = generate_table(data_avg_sparsity, 'ppl', highlight_min=True)
    tmp_pivot_style_acc = generate_table(data_avg_sparsity, 'acc')
    tmp_pivot_style_bleu = generate_table(data_avg_sparsity, 'bleu')
    tmp_pivot_style_f1 = generate_table(data_avg_sparsity, 'f1')

    print("\n\n\n\nAVG sparsity " + str(sparsity) + ": PPL")
    display(tmp_pivot_style_ppl)

    print("AVG sparsity " + str(sparsity) + ": ACC")
    display(tmp_pivot_style_acc)

    print("AVG sparsity " + str(sparsity) + ": BLEU")
    display(tmp_pivot_style_bleu)

    print("AVG sparsity " + str(sparsity) + ": F1")
    display(tmp_pivot_style_f1)
    


tmp_pivot_style_ppl = generate_table(data_avg, 'ppl', highlight_min=True)
tmp_pivot_style_acc = generate_table(data_avg, 'acc')
tmp_pivot_style_bleu = generate_table(data_avg, 'bleu')
tmp_pivot_style_f1 = generate_table(data_avg, 'f1')

print("\n\n\n\n")
print("*"*100)
print("\n\n\n\nAVG all sparsity: PPL")
display(tmp_pivot_style_ppl)

print("AVG all sparsity: ACC")
display(tmp_pivot_style_acc)

print("AVG all sparsity: BLEU")
display(tmp_pivot_style_bleu)

print("AVG all sparsity: F1")
display(tmp_pivot_style_f1)"""
# Out:
# '\nfor sparsity in sparsity_list:\n    data_avg_sparsity = data_avg[(data_avg[\'sparsity\'] == sparsity) | (data_avg[\'sparsity\'] == 0.0)]\n    tmp_pivot_style_ppl = generate_table(data_avg_sparsity, \'ppl\', highlight_min=True)\n    tmp_pivot_style_acc = generate_table(data_avg_sparsity, \'acc\')\n    tmp_pivot_style_bleu = generate_table(data_avg_sparsity, \'bleu\')\n    tmp_pivot_style_f1 = generate_table(data_avg_sparsity, \'f1\')\n\n    print("\n\n\n\nAVG sparsity " + str(sparsity) + ": PPL")\n    display(tmp_pivot_style_ppl)\n\n    print("AVG sparsity " + str(sparsity) + ": ACC")\n    display(tmp_pivot_style_acc)\n\n    print("AVG sparsity " + str(sparsity) + ": BLEU")\n    display(tmp_pivot_style_bleu)\n\n    print("AVG sparsity " + str(sparsity) + ": F1")\n    display(tmp_pivot_style_f1)\n    \n\n\ntmp_pivot_style_ppl = generate_table(data_avg, \'ppl\', highlight_min=True)\ntmp_pivot_style_acc = generate_table(data_avg, \'acc\')\ntmp_pivot_style_bleu = generate_table(data_avg, \'bleu\')\ntmp_pivot_style_f1 = generate_table(data_avg, \'f1\')\n\nprint("\n\n\n\n")\nprint("*"*100)\nprint("\n\n\n\nAVG all sparsity: PPL")\ndisplay(tmp_pivot_style_ppl)\n\nprint("AVG all sparsity: ACC")\ndisplay(tmp_pivot_style_acc)\n\nprint("AVG all sparsity: BLEU")\ndisplay(tmp_pivot_style_bleu)\n\nprint("AVG all sparsity: F1")\ndisplay(tmp_pivot_style_f1)'

# %%
def get_avg_across_model_normalized(data_avg, sparsity=0):
    avg_results_ppl = pd.DataFrame()
    avg_results_acc = pd.DataFrame()
    avg_results_bleu = pd.DataFrame()
    avg_results_f1 = pd.DataFrame()

    for model in data_avg['model'].unique():
        data_this_model = data_avg[(data_avg['model'] == model)]
        
        data_ppl = get_percentage_values(data_this_model[data_this_model['metric'] == 'ppl'], 'ppl')
        data_acc = get_percentage_values(data_this_model[data_this_model['metric'] == 'acc'], 'acc')
        data_bleu = get_percentage_values(data_this_model[data_this_model['metric'] == 'bleu'], 'bleu')
        data_f1 = get_percentage_values(data_this_model[data_this_model['metric'] == 'f1'], 'f1')
        
        avg_results_ppl = pd.concat([avg_results_ppl, data_ppl[['dataset', 'pruning_data', 'percentage']]])
        avg_results_acc = pd.concat([avg_results_acc, data_acc[['dataset', 'pruning_data', 'percentage']]])
        avg_results_bleu = pd.concat([avg_results_bleu, data_bleu[['dataset', 'pruning_data', 'percentage']]])
        avg_results_f1 = pd.concat([avg_results_f1, data_f1[['dataset', 'pruning_data', 'percentage']]])
        
    mean_ppl = avg_results_ppl.groupby(['dataset', 'pruning_data']).mean().reset_index()
    mean_acc = avg_results_acc.groupby(['dataset', 'pruning_data']).mean().reset_index()
    mean_bleu = avg_results_bleu.groupby(['dataset', 'pruning_data']).mean().reset_index()
    mean_f1 = avg_results_f1.groupby(['dataset', 'pruning_data']).mean().reset_index()
    
    table_ppl = get_table(mean_ppl)
    table_acc = get_table(mean_acc)
    table_bleu = get_table(mean_bleu)
    table_f1 = get_table(mean_f1)



    print("\n\n\n\nAVG, sparsity " + str(sparsity) + ": PPL")
    display(table_ppl)

    print("AVG, sparsity " + str(sparsity) + ": ACC")
    display(table_acc)

    print("AVG, sparsity " + str(sparsity) + ": BLEU")
    display(table_bleu)

    print("AVG, sparsity " + str(sparsity) + ": F1")
    display(table_f1)

"""
for sparsity in sparsity_list:
    data_avg_sparsity = data_avg[(data_avg['sparsity'] == sparsity) | (data_avg['sparsity'] == 0.0)]
    get_avg_across_model_normalized(data_avg_sparsity, sparsity)
    
"""

print("\n\n\n\n")
print("*"*100)

data_exclude_zeros = copy.deepcopy(data_avg)
"""data_exclude_zeros = data_exclude_zeros[~((data_exclude_zeros['model'] == 'baichuan-inc/Baichuan-7B') & (data_exclude_zeros['sparsity'] == 0.7))]
data_exclude_zeros = data_exclude_zeros[~((data_exclude_zeros['model'] == 'microsoft/phi-2') & (data_exclude_zeros['sparsity'] == 0.7))]
data_exclude_zeros = data_exclude_zeros[~((data_exclude_zeros['model'] == 'meta-llama/Llama-2-7b-hf') & (data_exclude_zeros['sparsity'] == 0.7))]
"""
data_exclude_zeros = data_exclude_zeros[data_exclude_zeros['sparsity'] != 0.9]
#data_exclude_zeros = data_exclude_zeros[data_exclude_zeros['sparsity'] != 0.7]

get_avg_across_model_normalized(data_exclude_zeros, "All")
# Out:
# ****************************************************************************************************
#
#
#
#
# AVG, sparsity All: PPL
# <style type="text/css">
# #T_db514 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_db514 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_db514_row0_col0, #T_db514_row1_col0, #T_db514_row2_col0, #T_db514_row3_col0, #T_db514_row4_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_db514_row0_col1, #T_db514_row0_col2, #T_db514_row0_col3, #T_db514_row0_col4, #T_db514_row0_col5, #T_db514_row0_col6, #T_db514_row0_col7, #T_db514_row0_col8, #T_db514_row0_col9, #T_db514_row0_col10, #T_db514_row0_col11, #T_db514_row0_col12, #T_db514_row0_col13, #T_db514_row0_col14, #T_db514_row0_col15, #T_db514_row0_col17, #T_db514_row0_col18, #T_db514_row0_col19, #T_db514_row0_col20, #T_db514_row1_col1, #T_db514_row1_col3, #T_db514_row1_col4, #T_db514_row1_col5, #T_db514_row1_col6, #T_db514_row1_col7, #T_db514_row1_col8, #T_db514_row1_col9, #T_db514_row1_col10, #T_db514_row1_col11, #T_db514_row1_col12, #T_db514_row1_col13, #T_db514_row1_col14, #T_db514_row1_col15, #T_db514_row1_col16, #T_db514_row1_col17, #T_db514_row1_col18, #T_db514_row1_col19, #T_db514_row1_col20, #T_db514_row2_col1, #T_db514_row2_col2, #T_db514_row2_col4, #T_db514_row2_col5, #T_db514_row2_col6, #T_db514_row2_col7, #T_db514_row2_col8, #T_db514_row2_col9, #T_db514_row2_col10, #T_db514_row2_col11, #T_db514_row2_col12, #T_db514_row2_col13, #T_db514_row2_col14, #T_db514_row2_col15, #T_db514_row2_col16, #T_db514_row2_col17, #T_db514_row2_col18, #T_db514_row2_col19, #T_db514_row2_col20, #T_db514_row3_col1, #T_db514_row3_col2, #T_db514_row3_col3, #T_db514_row3_col5, #T_db514_row3_col6, #T_db514_row3_col7, #T_db514_row3_col8, #T_db514_row3_col9, #T_db514_row3_col10, #T_db514_row3_col11, #T_db514_row3_col12, #T_db514_row3_col13, #T_db514_row3_col14, #T_db514_row3_col15, #T_db514_row3_col16, #T_db514_row3_col17, #T_db514_row3_col18, #T_db514_row3_col19, #T_db514_row3_col20, #T_db514_row4_col1, #T_db514_row4_col2, #T_db514_row4_col3, #T_db514_row4_col4, #T_db514_row4_col5, #T_db514_row4_col6, #T_db514_row4_col8, #T_db514_row4_col9, #T_db514_row4_col10, #T_db514_row4_col11, #T_db514_row4_col12, #T_db514_row4_col13, #T_db514_row4_col14, #T_db514_row4_col15, #T_db514_row4_col16, #T_db514_row4_col17, #T_db514_row4_col18, #T_db514_row4_col19, #T_db514_row4_col20 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_db514_row0_col16, #T_db514_row1_col2, #T_db514_row2_col3, #T_db514_row3_col4, #T_db514_row4_col7 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_db514">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th id="T_db514_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_db514_level0_col1" class="col_heading level0 col1" >C4</th>
#       <th id="T_db514_level0_col2" class="col_heading level0 col2" >OSCAR</th>
#       <th id="T_db514_level0_col3" class="col_heading level0 col3" >Pile</th>
#       <th id="T_db514_level0_col4" class="col_heading level0 col4" >RedPajama</th>
#       <th id="T_db514_level0_col5" class="col_heading level0 col5" >WikiText</th>
#       <th id="T_db514_level0_col6" class="col_heading level0 col6" >ANLI</th>
#       <th id="T_db514_level0_col7" class="col_heading level0 col7" >BoolQ</th>
#       <th id="T_db514_level0_col8" class="col_heading level0 col8" >CommonsenseQA</th>
#       <th id="T_db514_level0_col9" class="col_heading level0 col9" >e-SNLI</th>
#       <th id="T_db514_level0_col10" class="col_heading level0 col10" >GSM8K</th>
#       <th id="T_db514_level0_col11" class="col_heading level0 col11" >MAWPS</th>
#       <th id="T_db514_level0_col12" class="col_heading level0 col12" >RACE</th>
#       <th id="T_db514_level0_col13" class="col_heading level0 col13" >RTE</th>
#       <th id="T_db514_level0_col14" class="col_heading level0 col14" >SVAMP</th>
#       <th id="T_db514_level0_col15" class="col_heading level0 col15" >WinoGrande</th>
#       <th id="T_db514_level0_col16" class="col_heading level0 col16" >IWSLT</th>
#       <th id="T_db514_level0_col17" class="col_heading level0 col17" >WMT14</th>
#       <th id="T_db514_level0_col18" class="col_heading level0 col18" >DS1000</th>
#       <th id="T_db514_level0_col19" class="col_heading level0 col19" >MBPP</th>
#       <th id="T_db514_level0_col20" class="col_heading level0 col20" >RefineCode</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db514_level0_row0" class="row_heading level0 row0" >C4</th>
#       <td id="T_db514_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_db514_row0_col1" class="data row0 col1" >0.642</td>
#       <td id="T_db514_row0_col2" class="data row0 col2" >0.645</td>
#       <td id="T_db514_row0_col3" class="data row0 col3" >0.644</td>
#       <td id="T_db514_row0_col4" class="data row0 col4" >0.643</td>
#       <td id="T_db514_row0_col5" class="data row0 col5" >0.637</td>
#       <td id="T_db514_row0_col6" class="data row0 col6" >0.642</td>
#       <td id="T_db514_row0_col7" class="data row0 col7" >0.647</td>
#       <td id="T_db514_row0_col8" class="data row0 col8" >0.623</td>
#       <td id="T_db514_row0_col9" class="data row0 col9" >0.616</td>
#       <td id="T_db514_row0_col10" class="data row0 col10" >0.624</td>
#       <td id="T_db514_row0_col11" class="data row0 col11" >0.621</td>
#       <td id="T_db514_row0_col12" class="data row0 col12" >0.638</td>
#       <td id="T_db514_row0_col13" class="data row0 col13" >0.636</td>
#       <td id="T_db514_row0_col14" class="data row0 col14" >0.619</td>
#       <td id="T_db514_row0_col15" class="data row0 col15" >0.624</td>
#       <td id="T_db514_row0_col16" class="data row0 col16" >0.647</td>
#       <td id="T_db514_row0_col17" class="data row0 col17" >0.645</td>
#       <td id="T_db514_row0_col18" class="data row0 col18" >0.626</td>
#       <td id="T_db514_row0_col19" class="data row0 col19" >0.623</td>
#       <td id="T_db514_row0_col20" class="data row0 col20" >0.632</td>
#     </tr>
#     <tr>
#       <th id="T_db514_level0_row1" class="row_heading level0 row1" >OSCAR</th>
#       <td id="T_db514_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_db514_row1_col1" class="data row1 col1" >0.645</td>
#       <td id="T_db514_row1_col2" class="data row1 col2" >0.651</td>
#       <td id="T_db514_row1_col3" class="data row1 col3" >0.649</td>
#       <td id="T_db514_row1_col4" class="data row1 col4" >0.649</td>
#       <td id="T_db514_row1_col5" class="data row1 col5" >0.642</td>
#       <td id="T_db514_row1_col6" class="data row1 col6" >0.647</td>
#       <td id="T_db514_row1_col7" class="data row1 col7" >0.650</td>
#       <td id="T_db514_row1_col8" class="data row1 col8" >0.627</td>
#       <td id="T_db514_row1_col9" class="data row1 col9" >0.620</td>
#       <td id="T_db514_row1_col10" class="data row1 col10" >0.627</td>
#       <td id="T_db514_row1_col11" class="data row1 col11" >0.626</td>
#       <td id="T_db514_row1_col12" class="data row1 col12" >0.641</td>
#       <td id="T_db514_row1_col13" class="data row1 col13" >0.639</td>
#       <td id="T_db514_row1_col14" class="data row1 col14" >0.622</td>
#       <td id="T_db51
# AVG, sparsity All: ACC
# <style type="text/css">
# #T_44dce th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_44dce th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_44dce_row0_col0, #T_44dce_row1_col0, #T_44dce_row2_col0, #T_44dce_row3_col0, #T_44dce_row4_col0, #T_44dce_row5_col0, #T_44dce_row6_col0, #T_44dce_row7_col0, #T_44dce_row8_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_44dce_row0_col1, #T_44dce_row0_col2, #T_44dce_row0_col4, #T_44dce_row0_col5, #T_44dce_row0_col6, #T_44dce_row0_col7, #T_44dce_row0_col8, #T_44dce_row0_col9, #T_44dce_row0_col10, #T_44dce_row0_col11, #T_44dce_row0_col12, #T_44dce_row0_col13, #T_44dce_row0_col14, #T_44dce_row0_col15, #T_44dce_row0_col16, #T_44dce_row0_col17, #T_44dce_row0_col18, #T_44dce_row0_col19, #T_44dce_row0_col20, #T_44dce_row1_col1, #T_44dce_row1_col2, #T_44dce_row1_col4, #T_44dce_row1_col5, #T_44dce_row1_col6, #T_44dce_row1_col7, #T_44dce_row1_col8, #T_44dce_row1_col9, #T_44dce_row1_col10, #T_44dce_row1_col11, #T_44dce_row1_col12, #T_44dce_row1_col13, #T_44dce_row1_col14, #T_44dce_row1_col15, #T_44dce_row1_col16, #T_44dce_row1_col17, #T_44dce_row1_col18, #T_44dce_row1_col19, #T_44dce_row1_col20, #T_44dce_row2_col1, #T_44dce_row2_col2, #T_44dce_row2_col3, #T_44dce_row2_col4, #T_44dce_row2_col5, #T_44dce_row2_col6, #T_44dce_row2_col7, #T_44dce_row2_col8, #T_44dce_row2_col9, #T_44dce_row2_col10, #T_44dce_row2_col11, #T_44dce_row2_col12, #T_44dce_row2_col13, #T_44dce_row2_col15, #T_44dce_row2_col16, #T_44dce_row2_col17, #T_44dce_row2_col18, #T_44dce_row2_col19, #T_44dce_row2_col20, #T_44dce_row3_col1, #T_44dce_row3_col2, #T_44dce_row3_col4, #T_44dce_row3_col5, #T_44dce_row3_col6, #T_44dce_row3_col7, #T_44dce_row3_col8, #T_44dce_row3_col9, #T_44dce_row3_col10, #T_44dce_row3_col11, #T_44dce_row3_col12, #T_44dce_row3_col13, #T_44dce_row3_col14, #T_44dce_row3_col15, #T_44dce_row3_col16, #T_44dce_row3_col17, #T_44dce_row3_col18, #T_44dce_row3_col19, #T_44dce_row3_col20, #T_44dce_row4_col1, #T_44dce_row4_col2, #T_44dce_row4_col3, #T_44dce_row4_col4, #T_44dce_row4_col5, #T_44dce_row4_col6, #T_44dce_row4_col7, #T_44dce_row4_col8, #T_44dce_row4_col9, #T_44dce_row4_col10, #T_44dce_row4_col11, #T_44dce_row4_col13, #T_44dce_row4_col14, #T_44dce_row4_col15, #T_44dce_row4_col16, #T_44dce_row4_col17, #T_44dce_row4_col18, #T_44dce_row4_col19, #T_44dce_row4_col20, #T_44dce_row5_col1, #T_44dce_row5_col2, #T_44dce_row5_col3, #T_44dce_row5_col4, #T_44dce_row5_col5, #T_44dce_row5_col6, #T_44dce_row5_col7, #T_44dce_row5_col8, #T_44dce_row5_col9, #T_44dce_row5_col10, #T_44dce_row5_col11, #T_44dce_row5_col12, #T_44dce_row5_col14, #T_44dce_row5_col15, #T_44dce_row5_col16, #T_44dce_row5_col17, #T_44dce_row5_col18, #T_44dce_row5_col19, #T_44dce_row5_col20, #T_44dce_row6_col1, #T_44dce_row6_col2, #T_44dce_row6_col3, #T_44dce_row6_col4, #T_44dce_row6_col5, #T_44dce_row6_col6, #T_44dce_row6_col7, #T_44dce_row6_col8, #T_44dce_row6_col9, #T_44dce_row6_col10, #T_44dce_row6_col11, #T_44dce_row6_col12, #T_44dce_row6_col13, #T_44dce_row6_col14, #T_44dce_row6_col15, #T_44dce_row6_col16, #T_44dce_row6_col17, #T_44dce_row6_col19, #T_44dce_row6_col20, #T_44dce_row7_col1, #T_44dce_row7_col2, #T_44dce_row7_col3, #T_44dce_row7_col4, #T_44dce_row7_col5, #T_44dce_row7_col6, #T_44dce_row7_col7, #T_44dce_row7_col8, #T_44dce_row7_col9, #T_44dce_row7_col10, #T_44dce_row7_col11, #T_44dce_row7_col12, #T_44dce_row7_col13, #T_44dce_row7_col14, #T_44dce_row7_col15, #T_44dce_row7_col17, #T_44dce_row7_col18, #T_44dce_row7_col19, #T_44dce_row7_col20, #T_44dce_row8_col1, #T_44dce_row8_col2, #T_44dce_row8_col4, #T_44dce_row8_col5, #T_44dce_row8_col6, #T_44dce_row8_col7, #T_44dce_row8_col8, #T_44dce_row8_col9, #T_44dce_row8_col10, #T_44dce_row8_col11, #T_44dce_row8_col12, #T_44dce_row8_col13, #T_44dce_row8_col14, #T_44dce_row8_col15, #T_44dce_row8_col16, #T_44dce_row8_col17, #T_44dce_row8_col18, #T_44dce_row8_col19, #T_44dce_row8_col20 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_44dce_row0_col3, #T_44dce_row1_col3, #T_44dce_row2_col14, #T_44dce_row3_col3, #T_44dce_row4_col12, #T_44dce_row5_col13, #T_44dce_row6_col18, #T_44dce_row7_col16, #T_44dce_row8_col3 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_44dce">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th id="T_44dce_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_44dce_level0_col1" class="col_heading level0 col1" >C4</th>
#       <th id="T_44dce_level0_col2" class="col_heading level0 col2" >OSCAR</th>
#       <th id="T_44dce_level0_col3" class="col_heading level0 col3" >Pile</th>
#       <th id="T_44dce_level0_col4" class="col_heading level0 col4" >RedPajama</th>
#       <th id="T_44dce_level0_col5" class="col_heading level0 col5" >WikiText</th>
#       <th id="T_44dce_level0_col6" class="col_heading level0 col6" >ANLI</th>
#       <th id="T_44dce_level0_col7" class="col_heading level0 col7" >BoolQ</th>
#       <th id="T_44dce_level0_col8" class="col_heading level0 col8" >CommonsenseQA</th>
#       <th id="T_44dce_level0_col9" class="col_heading level0 col9" >e-SNLI</th>
#       <th id="T_44dce_level0_col10" class="col_heading level0 col10" >GSM8K</th>
#       <th id="T_44dce_level0_col11" class="col_heading level0 col11" >MAWPS</th>
#       <th id="T_44dce_level0_col12" class="col_heading level0 col12" >RACE</th>
#       <th id="T_44dce_level0_col13" class="col_heading level0 col13" >RTE</th>
#       <th id="T_44dce_level0_col14" class="col_heading level0 col14" >SVAMP</th>
#       <th id="T_44dce_level0_col15" class="col_heading level0 col15" >WinoGrande</th>
#       <th id="T_44dce_level0_col16" class="col_heading level0 col16" >IWSLT</th>
#       <th id="T_44dce_level0_col17" class="col_heading level0 col17" >WMT14</th>
#       <th id="T_44dce_level0_col18" class="col_heading level0 col18" >DS1000</th>
#       <th id="T_44dce_level0_col19" class="col_heading level0 col19" >MBPP</th>
#       <th id="T_44dce_level0_col20" class="col_heading level0 col20" >RefineCode</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44dce_level0_row0" class="row_heading level0 row0" >ANLI</th>
#       <td id="T_44dce_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_44dce_row0_col1" class="data row0 col1" >0.806</td>
#       <td id="T_44dce_row0_col2" class="data row0 col2" >0.791</td>
#       <td id="T_44dce_row0_col3" class="data row0 col3" >0.810</td>
#       <td id="T_44dce_row0_col4" class="data row0 col4" >0.792</td>
#       <td id="T_44dce_row0_col5" class="data row0 col5" >0.799</td>
#       <td id="T_44dce_row0_col6" class="data row0 col6" >0.805</td>
#       <td id="T_44dce_row0_col7" class="data row0 col7" >0.794</td>
#       <td id="T_44dce_row0_col8" class="data row0 col8" >0.793</td>
#       <td id="T_44dce_row0_col9" class="data row0 col9" >0.768</td>
#       <td id="T_44dce_row0_col10" class="data row0 col10" >0.790</td>
#       <td id="T_44dce_row0_col11" class="data row0 col11" >0.792</td>
#       <td id="T_44dce_row0_col12" class="data row0 c
# AVG, sparsity All: BLEU
# <style type="text/css">
# #T_82561 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_82561 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_82561_row0_col0, #T_82561_row1_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_82561_row0_col1, #T_82561_row0_col2, #T_82561_row0_col3, #T_82561_row0_col4, #T_82561_row0_col5, #T_82561_row0_col6, #T_82561_row0_col7, #T_82561_row0_col8, #T_82561_row0_col9, #T_82561_row0_col10, #T_82561_row0_col11, #T_82561_row0_col12, #T_82561_row0_col13, #T_82561_row0_col14, #T_82561_row0_col15, #T_82561_row0_col17, #T_82561_row0_col18, #T_82561_row0_col19, #T_82561_row0_col20, #T_82561_row1_col1, #T_82561_row1_col2, #T_82561_row1_col3, #T_82561_row1_col4, #T_82561_row1_col5, #T_82561_row1_col6, #T_82561_row1_col7, #T_82561_row1_col8, #T_82561_row1_col9, #T_82561_row1_col10, #T_82561_row1_col11, #T_82561_row1_col12, #T_82561_row1_col13, #T_82561_row1_col14, #T_82561_row1_col15, #T_82561_row1_col16, #T_82561_row1_col18, #T_82561_row1_col19, #T_82561_row1_col20 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_82561_row0_col16, #T_82561_row1_col17 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_82561">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th id="T_82561_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_82561_level0_col1" class="col_heading level0 col1" >C4</th>
#       <th id="T_82561_level0_col2" class="col_heading level0 col2" >OSCAR</th>
#       <th id="T_82561_level0_col3" class="col_heading level0 col3" >Pile</th>
#       <th id="T_82561_level0_col4" class="col_heading level0 col4" >RedPajama</th>
#       <th id="T_82561_level0_col5" class="col_heading level0 col5" >WikiText</th>
#       <th id="T_82561_level0_col6" class="col_heading level0 col6" >ANLI</th>
#       <th id="T_82561_level0_col7" class="col_heading level0 col7" >BoolQ</th>
#       <th id="T_82561_level0_col8" class="col_heading level0 col8" >CommonsenseQA</th>
#       <th id="T_82561_level0_col9" class="col_heading level0 col9" >e-SNLI</th>
#       <th id="T_82561_level0_col10" class="col_heading level0 col10" >GSM8K</th>
#       <th id="T_82561_level0_col11" class="col_heading level0 col11" >MAWPS</th>
#       <th id="T_82561_level0_col12" class="col_heading level0 col12" >RACE</th>
#       <th id="T_82561_level0_col13" class="col_heading level0 col13" >RTE</th>
#       <th id="T_82561_level0_col14" class="col_heading level0 col14" >SVAMP</th>
#       <th id="T_82561_level0_col15" class="col_heading level0 col15" >WinoGrande</th>
#       <th id="T_82561_level0_col16" class="col_heading level0 col16" >IWSLT</th>
#       <th id="T_82561_level0_col17" class="col_heading level0 col17" >WMT14</th>
#       <th id="T_82561_level0_col18" class="col_heading level0 col18" >DS1000</th>
#       <th id="T_82561_level0_col19" class="col_heading level0 col19" >MBPP</th>
#       <th id="T_82561_level0_col20" class="col_heading level0 col20" >RefineCode</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82561_level0_row0" class="row_heading level0 row0" >IWSLT</th>
#       <td id="T_82561_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_82561_row0_col1" class="data row0 col1" >0.615</td>
#       <td id="T_82561_row0_col2" class="data row0 col2" >0.620</td>
#       <td id="T_82561_row0_col3" class="data row0 col3" >0.625</td>
#       <td id="T_82561_row0_col4" class="data row0 col4" >0.620</td>
#       <td id="T_82561_row0_col5" class="data row0 col5" >0.607</td>
#       <td id="T_82561_row0_col6" class="data row0 col6" >0.617</td>
#       <td id="T_82561_row0_col7" class="data row0 col7" >0.607</td>
#       <td id="T_82561_row0_col8" class="data row0 col8" >0.599</td>
#       <td id="T_82561_row0_col9" class="data row0 col9" >0.597</td>
#       <td id="T_82561_row0_col10" class="data row0 col10" >0.596</td>
#       <td id="T_82561_row0_col11" class="data row0 col11" >0.616</td>
#       <td id="T_82561_row0_col12" class="data row0 col12" >0.600</td>
#       <td id="T_82561_row0_col13" class="data row0 col13" >0.611</td>
#       <td id="T_82561_row0_col14" class="data row0 col14" >0.604</td>
#       <td id="T_82561_row0_col15" class="data row0 col15" >0.607</td>
#       <td id="T_82561_row0_col16" class="data row0 col16" >0.652</td>
#       <td id="T_82561_row0_col17" class="data row0 col17" >0.651</td>
#       <td id="T_82561_row0_col18" class="data row0 col18" >0.611</td>
#       <td id="T_82561_row0_col19" class="data row0 col19" >0.605</td>
#       <td id="T_82561_row0_col20" class="data row0 col20" >0.611</td>
#     </tr>
#     <tr>
#       <th id="T_82561_level0_row1" class="row_heading level0 row1" >WMT14</th>
#       <td id="T_82561_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_82561_row1_col1" class="data row1 col1" >0.629</td>
#       <td id="T_82561_row1_col2" class="data row1 col2" >0.632</td>
#       <td id="T_82561_row1_col3" class="data row1 col3" >0.640</td>
#       <td id="T_82561_row1_col4" class="data row1 col4" >0.630</td>
#       <td id="T_82561_row1_col5" class="data row1 col5" >0.625</td>
#       <td id="T_82561_row1_col6" class="data row1 col6" >0.633</td>
#       <td id="T_82561_row1_col7" class="data row1 col7" >0.623</td>
#       <td id="T_82561_row1_col8" class="data row1 col8" >0.599</td>
#       <td id="T_82561_row1_col9" class="data row1 col9" >0.601</td>
#       <td id="T_82561_row1_col10" class="data row1 col10" >0.603</td>
#       <td id="T_82561_row1_col11" class="data row1 col11" >0.618</td>
#       <td id="T_82561_row1_col12" class="data row1 col12" >0.609</td>
#       <td id="T_82561_row1_col13" class="data row1 col13" >0.627</td>
#       <td id="T_82561_row1_col14" class="data row1 col14" >0.609</td>
#       <td id="T_82561_row1_col15" class="data row1 col15" >0.605</td>
#       <td id="T_82561_row1_col16" class="data row1 col16" >0.657</td>
#       <td id="T_82561_row1_col17" class="data row1 col17" >0.659</td>
#       <td id="T_82561_row1_col18" class="data row1 col18" >0.618</td>
#       <td id="T_82561_row1_col19" class="data row1 col19" >0.607</td>
#       <td id="T_82561_row1_col20" class="data row1 col20" >0.615</td>
#     </tr>
#   </tbody>
# </table>
# AVG, sparsity All: F1
# <style type="text/css">
# #T_02b3d th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_02b3d th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_02b3d_row0_col0, #T_02b3d_row1_col0, #T_02b3d_row2_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_02b3d_row0_col1, #T_02b3d_row0_col2, #T_02b3d_row0_col4, #T_02b3d_row0_col5, #T_02b3d_row0_col6, #T_02b3d_row0_col7, #T_02b3d_row0_col8, #T_02b3d_row0_col9, #T_02b3d_row0_col10, #T_02b3d_row0_col11, #T_02b3d_row0_col12, #T_02b3d_row0_col13, #T_02b3d_row0_col14, #T_02b3d_row0_col15, #T_02b3d_row0_col16, #T_02b3d_row0_col17, #T_02b3d_row0_col18, #T_02b3d_row0_col19, #T_02b3d_row0_col20, #T_02b3d_row1_col1, #T_02b3d_row1_col2, #T_02b3d_row1_col3, #T_02b3d_row1_col4, #T_02b3d_row1_col5, #T_02b3d_row1_col6, #T_02b3d_row1_col7, #T_02b3d_row1_col8, #T_02b3d_row1_col9, #T_02b3d_row1_col10, #T_02b3d_row1_col11, #T_02b3d_row1_col12, #T_02b3d_row1_col13, #T_02b3d_row1_col14, #T_02b3d_row1_col15, #T_02b3d_row1_col17, #T_02b3d_row1_col18, #T_02b3d_row1_col19, #T_02b3d_row1_col20, #T_02b3d_row2_col1, #T_02b3d_row2_col2, #T_02b3d_row2_col3, #T_02b3d_row2_col4, #T_02b3d_row2_col5, #T_02b3d_row2_col6, #T_02b3d_row2_col8, #T_02b3d_row2_col9, #T_02b3d_row2_col10, #T_02b3d_row2_col11, #T_02b3d_row2_col12, #T_02b3d_row2_col13, #T_02b3d_row2_col14, #T_02b3d_row2_col15, #T_02b3d_row2_col16, #T_02b3d_row2_col17, #T_02b3d_row2_col18, #T_02b3d_row2_col19, #T_02b3d_row2_col20 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_02b3d_row0_col3, #T_02b3d_row1_col16, #T_02b3d_row2_col7 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_02b3d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th id="T_02b3d_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_02b3d_level0_col1" class="col_heading level0 col1" >C4</th>
#       <th id="T_02b3d_level0_col2" class="col_heading level0 col2" >OSCAR</th>
#       <th id="T_02b3d_level0_col3" class="col_heading level0 col3" >Pile</th>
#       <th id="T_02b3d_level0_col4" class="col_heading level0 col4" >RedPajama</th>
#       <th id="T_02b3d_level0_col5" class="col_heading level0 col5" >WikiText</th>
#       <th id="T_02b3d_level0_col6" class="col_heading level0 col6" >ANLI</th>
#       <th id="T_02b3d_level0_col7" class="col_heading level0 col7" >BoolQ</th>
#       <th id="T_02b3d_level0_col8" class="col_heading level0 col8" >CommonsenseQA</th>
#       <th id="T_02b3d_level0_col9" class="col_heading level0 col9" >e-SNLI</th>
#       <th id="T_02b3d_level0_col10" class="col_heading level0 col10" >GSM8K</th>
#       <th id="T_02b3d_level0_col11" class="col_heading level0 col11" >MAWPS</th>
#       <th id="T_02b3d_level0_col12" class="col_heading level0 col12" >RACE</th>
#       <th id="T_02b3d_level0_col13" class="col_heading level0 col13" >RTE</th>
#       <th id="T_02b3d_level0_col14" class="col_heading level0 col14" >SVAMP</th>
#       <th id="T_02b3d_level0_col15" class="col_heading level0 col15" >WinoGrande</th>
#       <th id="T_02b3d_level0_col16" class="col_heading level0 col16" >IWSLT</th>
#       <th id="T_02b3d_level0_col17" class="col_heading level0 col17" >WMT14</th>
#       <th id="T_02b3d_level0_col18" class="col_heading level0 col18" >DS1000</th>
#       <th id="T_02b3d_level0_col19" class="col_heading level0 col19" >MBPP</th>
#       <th id="T_02b3d_level0_col20" class="col_heading level0 col20" >RefineCode</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02b3d_level0_row0" class="row_heading level0 row0" >DS1000</th>
#       <td id="T_02b3d_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_02b3d_row0_col1" class="data row0 col1" >0.931</td>
#       <td id="T_02b3d_row0_col2" class="data row0 col2" >0.938</td>
#       <td id="T_02b3d_row0_col3" class="data row0 col3" >0.943</td>
#       <td id="T_02b3d_row0_col4" class="data row0 col4" >0.929</td>
#       <td id="T_02b3d_row0_col5" class="data row0 col5" >0.929</td>
#       <td id="T_02b3d_row0_col6" class="data row0 col6" >0.904</td>
#       <td id="T_02b3d_row0_col7" class="data row0 col7" >0.917</td>
#       <td id="T_02b3d_row0_col8" class="data row0 col8" >0.894</td>
#       <td id="T_02b3d_row0_col9" class="data row0 col9" >0.934</td>
#       <td id="T_02b3d_row0_col10" class="data row0 col10" >0.919</td>
#       <td id="T_02b3d_row0_col11" class="data row0 col11" >0.883</td>
#       <td id="T_02b3d_row0_col12" class="data row0 col12" >0.905</td>
#       <td id="T_02b3d_row0_col13" class="data row0 col13" >0.907</td>
#       <td id="T_02b3d_row0_col14" class="data row0 col14" >0.900</td>
#       <td id="T_02b3d_row0_col15" class="data row0 col15" >0.912</td>
#       <td id="T_02b3d_row0_col16" class="data row0 col16" >0.901</td>
#       <td id="T_02b3d_row0_col17" class="data row0 col17" >0.910</td>
#       <td id="T_02b3d_row0_col18" class="data row0 col18" >0.943</td>
#       <td id="T_02b3d_row0_col19" class="data row0 col19" >0.938</td>
#       <td id="T_02b3d_row0_col20" class="data row0 col20" >0.938</td>
#     </tr>
#     <tr>
#       <th id="T_02b3d_level0_row1" class="row_heading level0 row1" >MBPP</th>
#       <td id="T_02b3d_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_02b3d_row1_col1" class="data row1 col1" >0.922</td>
#       <td id="T_02b3d_row1_col2" class="data row1 col2" >0.944</td>
#       <td id="T_02b3d_row1_col3" class="data row1 col3" >0.944</td>
#       <td id="T_02b3d_row1_col4" class="data row1 col4" >0.906</td>
#       <td id="T_02b3d_row1_col5" class="data row1 col5" >0.904</td>
#       <td id="T_02b3d_row1_col6" class="data row1 col6" >0.919</td>
#       <td id="T_02b3d_row1_col7" class="data row1 col7" >0.941</td>
#       <td id="T_02b3d_row1_col8" class="data row1 col8" >0.930</td>
#       <td id="T_02b3d_row1_col9" class="data row1 col9" >0.882</td>
#       <td id="T_02b3d_row1_col10" class="data row1 col10" >0.938</td>
#       <td id="T_02b3d_row1_col11" class="data row1 col11" >0.914</td>
#       <td id="T_02b3d_row1_col12" class="data row1 col12" >0.924</td>
#       <td id="T_02b3d_row1_col13" class="data row1 col13" >0.905</td>
#       <td id="T_02b3d_row1_col14" class="data row1 col14" >0.898</td>
#       <td id="T_02b3d_row1_col15" class="data row1 col15" >0.948</td>
#       <td id="T_02b3d_row1_col16" class="data row1 col16" >0.949</td>
#       <td id="T_02b3d_row1_col17" class="data row1 col17" >0.921</td>
#       <td id="T_02b3d_row1_col18" class="data row1 col18" >0.913</td>
#       <td id="T_02b3d_row1_col19" class="data row1 col19" >0.939</td>
#       <td id="T_02b3d_row1_col20" class="data row1 col20" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_02b3d_level0_row2" class="row_heading level0 row2" >RefineCode</th>
#       <td id="T_02b3d_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_02b3d_row2_col1" class="data row2 col1" >0.918</td>
#       <td id="T_02b3d_row2_col2" class="data row2 col2" >0.931</td>
#       <td id="T_02b3d_row2_col3" class="data row2 col3" >0.929</td>
#       <td id="T_02b3d_row2_col4" class="data row2 col4" >0.900</td>
#       <td id="T_

# %%
def get_avg_across_model_normalized_task(data_avg, sparsity=0):
    avg_results_ppl = pd.DataFrame()
    avg_results_acc = pd.DataFrame()
    avg_results_bleu = pd.DataFrame()
    avg_results_f1 = pd.DataFrame()

    for model in data_avg['model'].unique():
        data_this_model = data_avg[data_avg['model'] == model]
        
        data_ppl = get_percentage_values(data_this_model[data_this_model['metric'] == 'ppl'], 'ppl')
        data_acc = get_percentage_values(data_this_model[data_this_model['metric'] == 'acc'], 'acc')
        data_bleu = get_percentage_values(data_this_model[data_this_model['metric'] == 'bleu'], 'bleu')
        data_f1 = get_percentage_values(data_this_model[data_this_model['metric'] == 'f1'], 'f1')
        
        data_ppl = data_ppl.groupby(['dataset_group', 'pruning_group']).agg(percentage_group=('percentage', 'mean'))
        data_acc = data_acc.groupby(['dataset_group', 'pruning_group']).agg(percentage_group=('percentage', 'mean'))
        data_bleu = data_bleu.groupby(['dataset_group', 'pruning_group']).agg(percentage_group=('percentage', 'mean'))
        data_f1 = data_f1.groupby(['dataset_group', 'pruning_group']).agg(percentage_group=('percentage', 'mean'))
        
        avg_results_ppl = pd.concat([avg_results_ppl, data_ppl])
        avg_results_acc = pd.concat([avg_results_acc, data_acc])
        avg_results_bleu = pd.concat([avg_results_bleu, data_bleu])
        avg_results_f1 = pd.concat([avg_results_f1, data_f1])

    mean_ppl = avg_results_ppl.groupby(['dataset_group', 'pruning_group']).mean().reset_index()
    mean_acc = avg_results_acc.groupby(['dataset_group', 'pruning_group']).mean().reset_index()
    mean_bleu = avg_results_bleu.groupby(['dataset_group', 'pruning_group']).mean().reset_index()
    mean_f1 = avg_results_f1.groupby(['dataset_group', 'pruning_group']).mean().reset_index()

    table_ppl = get_table_task(mean_ppl)
    table_acc = get_table_task(mean_acc)
    table_bleu = get_table_task(mean_bleu)
    table_f1 = get_table_task(mean_f1)


    print("\n\n\n\nAVG, sparsity " + str(sparsity) + ": PPL")
    display(table_ppl)

    print("AVG, sparsity " + str(sparsity) + ": ACC")
    display(table_acc)

    print("AVG, sparsity " + str(sparsity) + ": BLEU")
    display(table_bleu)

    print("AVG, sparsity " + str(sparsity) + ": F1")
    display(table_f1)
    


"""
for sparsity in sparsity_list:
    data_avg_sparsity = data_avg[(data_avg['sparsity'] == sparsity) | (data_avg['sparsity'] == 0.0)]
    get_avg_across_model_normalized_task(data_avg_sparsity, sparsity)
"""


print("\n\n\n\n")
print("*"*100)


data_exclude_zeros = copy.deepcopy(data_avg)
"""data_exclude_zeros = data_exclude_zeros[~((data_exclude_zeros['model'] == 'baichuan-inc/Baichuan-7B') & (data_exclude_zeros['sparsity'] == 0.7))]
data_exclude_zeros = data_exclude_zeros[~((data_exclude_zeros['model'] == 'microsoft/phi-2') & (data_exclude_zeros['sparsity'] == 0.7))]
data_exclude_zeros = data_exclude_zeros[~((data_exclude_zeros['model'] == 'meta-llama/Llama-2-7b-hf') & (data_exclude_zeros['sparsity'] == 0.7))]"""
data_exclude_zeros = data_exclude_zeros[(data_exclude_zeros['sparsity'] != 0.9)]
#data_exclude_zeros = data_exclude_zeros[data_exclude_zeros['sparsity'] != 0.7]


get_avg_across_model_normalized_task(data_exclude_zeros, 0.0)
#get_avg_across_model_normalized_task(data_avg, 0.0)
# Out:
# ****************************************************************************************************
#
#
#
#
# AVG, sparsity 0.0: PPL
# <style type="text/css">
# #T_4a13f th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_4a13f th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_4a13f_row0_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_4a13f_row0_col1, #T_4a13f_row0_col2, #T_4a13f_row0_col3, #T_4a13f_row0_col4, #T_4a13f_row0_col6 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_4a13f_row0_col5 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_4a13f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_group</th>
#       <th id="T_4a13f_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_4a13f_level0_col1" class="col_heading level0 col1" >Language Modeling</th>
#       <th id="T_4a13f_level0_col2" class="col_heading level0 col2" >Mathematical Reasoning</th>
#       <th id="T_4a13f_level0_col3" class="col_heading level0 col3" >NLI</th>
#       <th id="T_4a13f_level0_col4" class="col_heading level0 col4" >Question Answering</th>
#       <th id="T_4a13f_level0_col5" class="col_heading level0 col5" >Translation</th>
#       <th id="T_4a13f_level0_col6" class="col_heading level0 col6" >Coding</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a13f_level0_row0" class="row_heading level0 row0" >Language Modeling</th>
#       <td id="T_4a13f_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_4a13f_row0_col1" class="data row0 col1" >0.652</td>
#       <td id="T_4a13f_row0_col2" class="data row0 col2" >0.631</td>
#       <td id="T_4a13f_row0_col3" class="data row0 col3" >0.641</td>
#       <td id="T_4a13f_row0_col4" class="data row0 col4" >0.641</td>
#       <td id="T_4a13f_row0_col5" class="data row0 col5" >0.654</td>
#       <td id="T_4a13f_row0_col6" class="data row0 col6" >0.640</td>
#     </tr>
#   </tbody>
# </table>
# AVG, sparsity 0.0: ACC
# <style type="text/css">
# #T_93440 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_93440 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_93440_row0_col0, #T_93440_row1_col0, #T_93440_row2_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_93440_row0_col1, #T_93440_row0_col3, #T_93440_row0_col4, #T_93440_row0_col5, #T_93440_row0_col6, #T_93440_row1_col2, #T_93440_row1_col3, #T_93440_row1_col4, #T_93440_row1_col5, #T_93440_row1_col6, #T_93440_row2_col2, #T_93440_row2_col3, #T_93440_row2_col4, #T_93440_row2_col5, #T_93440_row2_col6 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_93440_row0_col2, #T_93440_row1_col1, #T_93440_row2_col1 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_93440">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_group</th>
#       <th id="T_93440_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_93440_level0_col1" class="col_heading level0 col1" >Language Modeling</th>
#       <th id="T_93440_level0_col2" class="col_heading level0 col2" >Mathematical Reasoning</th>
#       <th id="T_93440_level0_col3" class="col_heading level0 col3" >NLI</th>
#       <th id="T_93440_level0_col4" class="col_heading level0 col4" >Question Answering</th>
#       <th id="T_93440_level0_col5" class="col_heading level0 col5" >Translation</th>
#       <th id="T_93440_level0_col6" class="col_heading level0 col6" >Coding</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93440_level0_row0" class="row_heading level0 row0" >Mathematical Reasoning</th>
#       <td id="T_93440_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_93440_row0_col1" class="data row0 col1" >0.672</td>
#       <td id="T_93440_row0_col2" class="data row0 col2" >0.681</td>
#       <td id="T_93440_row0_col3" class="data row0 col3" >0.636</td>
#       <td id="T_93440_row0_col4" class="data row0 col4" >0.643</td>
#       <td id="T_93440_row0_col5" class="data row0 col5" >0.631</td>
#       <td id="T_93440_row0_col6" class="data row0 col6" >0.671</td>
#     </tr>
#     <tr>
#       <th id="T_93440_level0_row1" class="row_heading level0 row1" >NLI</th>
#       <td id="T_93440_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_93440_row1_col1" class="data row1 col1" >0.804</td>
#       <td id="T_93440_row1_col2" class="data row1 col2" >0.789</td>
#       <td id="T_93440_row1_col3" class="data row1 col3" >0.802</td>
#       <td id="T_93440_row1_col4" class="data row1 col4" >0.792</td>
#       <td id="T_93440_row1_col5" class="data row1 col5" >0.793</td>
#       <td id="T_93440_row1_col6" class="data row1 col6" >0.792</td>
#     </tr>
#     <tr>
#       <th id="T_93440_level0_row2" class="row_heading level0 row2" >Question Answering</th>
#       <td id="T_93440_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_93440_row2_col1" class="data row2 col1" >0.840</td>
#       <td id="T_93440_row2_col2" class="data row2 col2" >0.812</td>
#       <td id="T_93440_row2_col3" class="data row2 col3" >0.804</td>
#       <td id="T_93440_row2_col4" class="data row2 col4" >0.822</td>
#       <td id="T_93440_row2_col5" class="data row2 col5" >0.796</td>
#       <td id="T_93440_row2_col6" class="data row2 col6" >0.818</td>
#     </tr>
#   </tbody>
# </table>
# AVG, sparsity 0.0: BLEU
# <style type="text/css">
# #T_a7684 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_a7684 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_a7684_row0_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_a7684_row0_col1, #T_a7684_row0_col2, #T_a7684_row0_col3, #T_a7684_row0_col4, #T_a7684_row0_col6 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_a7684_row0_col5 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_a7684">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_group</th>
#       <th id="T_a7684_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_a7684_level0_col1" class="col_heading level0 col1" >Language Modeling</th>
#       <th id="T_a7684_level0_col2" class="col_heading level0 col2" >Mathematical Reasoning</th>
#       <th id="T_a7684_level0_col3" class="col_heading level0 col3" >NLI</th>
#       <th id="T_a7684_level0_col4" class="col_heading level0 col4" >Question Answering</th>
#       <th id="T_a7684_level0_col5" class="col_heading level0 col5" >Translation</th>
#       <th id="T_a7684_level0_col6" class="col_heading level0 col6" >Coding</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7684_level0_row0" class="row_heading level0 row0" >Translation</th>
#       <td id="T_a7684_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_a7684_row0_col1" class="data row0 col1" >0.624</td>
#       <td id="T_a7684_row0_col2" class="data row0 col2" >0.608</td>
#       <td id="T_a7684_row0_col3" class="data row0 col3" >0.614</td>
#       <td id="T_a7684_row0_col4" class="data row0 col4" >0.606</td>
#       <td id="T_a7684_row0_col5" class="data row0 col5" >0.655</td>
#       <td id="T_a7684_row0_col6" class="data row0 col6" >0.611</td>
#     </tr>
#   </tbody>
# </table>
# AVG, sparsity 0.0: F1
# <style type="text/css">
# #T_682d0 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_682d0 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_682d0_row0_col0 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# #T_682d0_row0_col1, #T_682d0_row0_col2, #T_682d0_row0_col3, #T_682d0_row0_col4, #T_682d0_row0_col5 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_682d0_row0_col6 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_682d0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pruning_group</th>
#       <th id="T_682d0_level0_col0" class="col_heading level0 col0" >Dense</th>
#       <th id="T_682d0_level0_col1" class="col_heading level0 col1" >Language Modeling</th>
#       <th id="T_682d0_level0_col2" class="col_heading level0 col2" >Mathematical Reasoning</th>
#       <th id="T_682d0_level0_col3" class="col_heading level0 col3" >NLI</th>
#       <th id="T_682d0_level0_col4" class="col_heading level0 col4" >Question Answering</th>
#       <th id="T_682d0_level0_col5" class="col_heading level0 col5" >Translation</th>
#       <th id="T_682d0_level0_col6" class="col_heading level0 col6" >Coding</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_682d0_level0_row0" class="row_heading level0 row0" >Coding</th>
#       <td id="T_682d0_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_682d0_row0_col1" class="data row0 col1" >0.924</td>
#       <td id="T_682d0_row0_col2" class="data row0 col2" >0.910</td>
#       <td id="T_682d0_row0_col3" class="data row0 col3" >0.906</td>
#       <td id="T_682d0_row0_col4" class="data row0 col4" >0.924</td>
#       <td id="T_682d0_row0_col5" class="data row0 col5" >0.922</td>
#       <td id="T_682d0_row0_col6" class="data row0 col6" >0.932</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h1>Using multiple calibration dataset</h1>

# %%
#order_columns_with_mean = ['dense', 'random_sample', 'prototype_flatten', 'prototype_mean', 'most_different_flatten', 'most_different_mean']  + order_columns[1:] #Salto dense
order_columns_with_mean = ['dense', 'random_sample', 'prototype_flatten', 'prototype_mean', 'most_different_flatten', 'most_different_mean', 'all_prototype_iou', 'all_prototype_iou_count_occurrence', 'all_most_different_iou', 'all_most_different_iou_count_occurrence', 'all_prototype_st', 'all_most_different_st']  + order_columns[1:] #Salto dense


#results = pd.read_csv("./results.csv")

results_leave_calibration_out = results#[results['model'] == "meta-llama/Llama-2-7b-hf"] #meta-llama/Llama-2-7b-hf, mistralai/Mistral-7B-v0.1, microsoft/phi-2, baichuan-inc/Baichuan-7B, Qwen/Qwen2.5-7B
results_leave_calibration_out['percentage'] = pd.NA

results_leave_calibration_out = results_leave_calibration_out[~((results_leave_calibration_out['model'] == 'Baichuan') & (results_leave_calibration_out['dataset'] == 'BoolQ'))]
results_leave_calibration_out = results_leave_calibration_out[~((results_leave_calibration_out['model'] == 'Qwen') & (results_leave_calibration_out['dataset'] == 'RACE'))]
results_leave_calibration_out = results_leave_calibration_out[results_leave_calibration_out['dataset'] != 'GSM8K'] #Attualmente non ha valori sensati

# %%
def create_plot_avg_calib(data):
    
    pivot_table = (
    pd.pivot_table(
        data = data.round(precision),
        index='pruning_data',
        columns='data',
        values='percentage'
        ).reindex(order_columns_with_mean, axis=0).reindex(
            ['PPL', 'ACC', 'BLEU', 'F1', 'AVG_across_metrics', 'AVG_across_datasets'], axis=1)
    )
    #pivot_table = pivot_table.T
    
    
    pivot_table_style = (
    pivot_table
        .style
            .set_table_styles([headers,index_style])
            .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
            .highlight_max(axis=0, color="red")
            #.highlight_max(pivot_table.index[1:], axis=0, color="yellow")
            .format(precision=precision)
    )
    
    return pivot_table_style



def get_avg_across_model_grouped_by_pruning_dataset(results_leave_calibration_out, sparsity=0):
    avg_results = pd.DataFrame()
    mean_across_dataset = pd.DataFrame()

    for model in results_leave_calibration_out['model'].unique():
        data_this_model = results_leave_calibration_out[(results_leave_calibration_out['model'] == model)]
        data_this_model = data_this_model[~data_this_model['pruning_data'].str.contains('_no_')]

        data_ppl = get_percentage_values(data_this_model[data_this_model['metric'] == 'ppl'], 'ppl')
        data_acc = get_percentage_values(data_this_model[data_this_model['metric'] == 'acc'], 'acc')
        data_bleu = get_percentage_values(data_this_model[data_this_model['metric'] == 'bleu'], 'bleu')
        data_f1 = get_percentage_values(data_this_model[data_this_model['metric'] == 'f1'], 'f1')
        
        data_ppl['data'] = 'PPL'
        data_acc['data'] = 'ACC'
        data_bleu['data'] = 'BLEU'
        data_f1['data'] = 'F1'

        data_ppl_groupped = data_ppl.groupby(['pruning_data', 'data']).agg({'percentage': 'mean'}).reset_index()
        data_acc_groupped = data_acc.groupby(['pruning_data', 'data']).agg({'percentage': 'mean'}).reset_index() 
        data_bleu_groupped = data_bleu.groupby(['pruning_data', 'data']).agg({'percentage': 'mean'}).reset_index() 
        data_f1_groupped = data_f1.groupby(['pruning_data', 'data']).agg({'percentage': 'mean'}).reset_index()

        avg_results = pd.concat([avg_results, data_ppl_groupped, data_acc_groupped, data_bleu_groupped, data_f1_groupped], ignore_index=True)
        mean_across_dataset = pd.concat([mean_across_dataset, data_ppl, data_acc, data_bleu, data_f1], ignore_index=True)


    mean_across_dataset = mean_across_dataset.groupby(['pruning_data']).agg({'percentage': 'mean'}).reset_index()
    mean_across_dataset['data'] = 'AVG_across_datasets'

    mean_across_tasks = avg_results.groupby('pruning_data').agg({'percentage': 'mean'}).reset_index()
    mean_across_tasks['data'] = 'AVG_across_metrics'

    mean = avg_results.groupby(['pruning_data', 'data']).agg({'percentage': 'mean'}).reset_index()

    final_results = pd.concat([mean, mean_across_tasks, mean_across_dataset], axis=0)
    table = create_plot_avg_calib(final_results)

    print("AVG, sparsity " + str(sparsity) + ": PPL, ACC, BLEU, F1")
    display(table)
    
    return mean


for sparsity in sparsity_list:
    data_avg_sparsity = results_leave_calibration_out[(results_leave_calibration_out['sparsity'] == sparsity) | (results_leave_calibration_out['sparsity'] == 0.0)]
    _ = get_avg_across_model_grouped_by_pruning_dataset(data_avg_sparsity, sparsity)
    

print("\n\n\n\n")
print("*"*100)
get_avg_across_model_grouped_by_pruning_dataset(results_leave_calibration_out, 0.5)
# Out:
# AVG, sparsity 0.1: PPL, ACC, BLEU, F1
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# <style type="text/css">
# #T_8c66a th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_8c66a th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_8c66a_row0_col0, #T_8c66a_row0_col1, #T_8c66a_row0_col2, #T_8c66a_row0_col3, #T_8c66a_row0_col4, #T_8c66a_row0_col5, #T_8c66a_row1_col0, #T_8c66a_row1_col1, #T_8c66a_row1_col2, #T_8c66a_row1_col3, #T_8c66a_row1_col4, #T_8c66a_row1_col5, #T_8c66a_row2_col0, #T_8c66a_row2_col1, #T_8c66a_row2_col2, #T_8c66a_row2_col3, #T_8c66a_row2_col4, #T_8c66a_row2_col5, #T_8c66a_row3_col0, #T_8c66a_row3_col1, #T_8c66a_row3_col2, #T_8c66a_row3_col3, #T_8c66a_row3_col4, #T_8c66a_row3_col5, #T_8c66a_row4_col0, #T_8c66a_row4_col1, #T_8c66a_row4_col2, #T_8c66a_row4_col3, #T_8c66a_row4_col4, #T_8c66a_row4_col5, #T_8c66a_row5_col0, #T_8c66a_row5_col1, #T_8c66a_row5_col2, #T_8c66a_row5_col3, #T_8c66a_row5_col4, #T_8c66a_row5_col5, #T_8c66a_row6_col0, #T_8c66a_row6_col1, #T_8c66a_row6_col2, #T_8c66a_row6_col3, #T_8c66a_row6_col4, #T_8c66a_row6_col5, #T_8c66a_row7_col0, #T_8c66a_row7_col1, #T_8c66a_row7_col2, #T_8c66a_row7_col3, #T_8c66a_row7_col4, #T_8c66a_row7_col5, #T_8c66a_row8_col0, #T_8c66a_row8_col1, #T_8c66a_row8_col2, #T_8c66a_row8_col3, #T_8c66a_row8_col4, #T_8c66a_row8_col5, #T_8c66a_row9_col0, #T_8c66a_row9_col1, #T_8c66a_row9_col2, #T_8c66a_row9_col3, #T_8c66a_row9_col4, #T_8c66a_row9_col5, #T_8c66a_row10_col0, #T_8c66a_row10_col1, #T_8c66a_row10_col2, #T_8c66a_row10_col3, #T_8c66a_row10_col4, #T_8c66a_row10_col5, #T_8c66a_row11_col0, #T_8c66a_row11_col1, #T_8c66a_row11_col2, #T_8c66a_row11_col3, #T_8c66a_row11_col4, #T_8c66a_row11_col5, #T_8c66a_row12_col0, #T_8c66a_row12_col1, #T_8c66a_row12_col2, #T_8c66a_row12_col3, #T_8c66a_row12_col4, #T_8c66a_row12_col5, #T_8c66a_row13_col0, #T_8c66a_row13_col1, #T_8c66a_row13_col2, #T_8c66a_row13_col3, #T_8c66a_row13_col4, #T_8c66a_row13_col5, #T_8c66a_row14_col0, #T_8c66a_row14_col1, #T_8c66a_row14_col3, #T_8c66a_row14_col4, #T_8c66a_row14_col5, #T_8c66a_row15_col0, #T_8c66a_row15_col1, #T_8c66a_row15_col2, #T_8c66a_row15_col3, #T_8c66a_row15_col4, #T_8c66a_row15_col5, #T_8c66a_row16_col0, #T_8c66a_row16_col1, #T_8c66a_row16_col2, #T_8c66a_row16_col3, #T_8c66a_row16_col4, #T_8c66a_row16_col5, #T_8c66a_row17_col0, #T_8c66a_row17_col1, #T_8c66a_row17_col2, #T_8c66a_row17_col3, #T_8c66a_row17_col4, #T_8c66a_row17_col5, #T_8c66a_row18_col1, #T_8c66a_row18_col2, #T_8c66a_row18_col3, #T_8c66a_row18_col4, #T_8c66a_row18_col5, #T_8c66a_row19_col0, #T_8c66a_row19_col1, #T_8c66a_row19_col2, #T_8c66a_row19_col3, #T_8c66a_row19_col4, #T_8c66a_row19_col5, #T_8c66a_row20_col0, #T_8c66a_row20_col1, #T_8c66a_row20_col2, #T_8c66a_row20_col3, #T_8c66a_row20_col4, #T_8c66a_row20_col5, #T_8c66a_row21_col0, #T_8c66a_row21_col1, #T_8c66a_row21_col2, #T_8c66a_row21_col3, #T_8c66a_row21_col4, #T_8c66a_row21_col5, #T_8c66a_row22_col0, #T_8c66a_row22_col1, #T_8c66a_row22_col2, #T_8c66a_row22_col3, #T_8c66a_row22_col4, #T_8c66a_row22_col5, #T_8c66a_row23_col0, #T_8c66a_row23_col2, #T_8c66a_row23_col3, #T_8c66a_row24_col0, #T_8c66a_row24_col1, #T_8c66a_row24_col2, #T_8c66a_row24_col3, #T_8c66a_row24_col4, #T_8c66a_row24_col5, #T_8c66a_row25_col0, #T_8c66a_row25_col1, #T_8c66a_row25_col2, #T_8c66a_row25_col3, #T_8c66a_row25_col4, #T_8c66a_row25_col5, #T_8c66a_row26_col0, #T_8c66a_row26_col1, #T_8c66a_row26_col2, #T_8c66a_row26_col3, #T_8c66a_row26_col4, #T_8c66a_row26_col5, #T_8c66a_row27_col0, #T_8c66a_row27_col1, #T_8c66a_row27_col2, #T_8c66a_row27_col3, #T_8c66a_row27_col4, #T_8c66a_row27_col5, #T_8c66a_row28_col0, #T_8c66a_row28_col1, #T_8c66a_row28_col2, #T_8c66a_row28_col3, #T_8c66a_row28_col4, #T_8c66a_row28_col5, #T_8c66a_row29_col0, #T_8c66a_row29_col1, #T_8c66a_row29_col2, #T_8c66a_row29_col3, #T_8c66a_row29_col4, #T_8c66a_row29_col5, #T_8c66a_row30_col0, #T_8c66a_row30_col1, #T_8c66a_row30_col2, #T_8c66a_row30_col4, #T_8c66a_row30_col5, #T_8c66a_row31_col0, #T_8c66a_row31_col1, #T_8c66a_row31_col2, #T_8c66a_row31_col3, #T_8c66a_row31_col4, #T_8c66a_row31_col5 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_8c66a_row14_col2, #T_8c66a_row18_col0, #T_8c66a_row23_col1, #T_8c66a_row23_col4, #T_8c66a_row23_col5, #T_8c66a_row30_col3 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# </style>
# <table id="T_8c66a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >data</th>
#       <th id="T_8c66a_level0_col0" class="col_heading level0 col0" >PPL</th>
#       <th id="T_8c66a_level0_col1" class="col_heading level0 col1" >ACC</th>
#       <th id="T_8c66a_level0_col2" class="col_heading level0 col2" >BLEU</th>
#       <th id="T_8c66a_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_8c66a_level0_col4" class="col_heading level0 col4" >AVG_across_metrics</th>
#       <th id="T_8c66a_level0_col5" class="col_heading level0 col5" >AVG_across_datasets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c66a_level0_row0" class="row_heading level0 row0" >dense</th>
#       <td id="T_8c66a_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_8c66a_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_8c66a_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8c66a_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_8c66a_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_8c66a_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c66a_level0_row1" class="row_heading level0 row1" >random_sample</th>
#       <td id="T_8c66a_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_8c66a_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_8c66a_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_8c66a_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_8c66a_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_8c66a_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c66a_level0_row2" class="row_heading level0 row2" >prototype_flatten</th>
#       <td id="T_8c66a_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_8c66a_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_8c66a_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_8c66a_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_8c66a_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_8c66a_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c66a_level0_row3" class="row_heading level0 row3" >prototype_mean</th>
#       <td id="T_8c66a_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_8c66a_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_8c66a_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_8c66a_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_8c66a_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_8c66a_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c66a_level0_row4" class="row_heading level0 row4" >most_different_flatten</th>
#       <td id="T_8c66a_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_8c66a_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_8c66a_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_8c66a_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_8c66a_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_8c66a_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c66a_level0_row5" class="row_heading level0 row5" >most_different_mean</th>
#       <td id="T_8c66a_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_8c66a_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_8c66a_row5_col2" class="da
# AVG, sparsity 0.3: PPL, ACC, BLEU, F1
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# <style type="text/css">
# #T_234b7 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_234b7 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_234b7_row0_col0, #T_234b7_row0_col1, #T_234b7_row0_col2, #T_234b7_row0_col3, #T_234b7_row0_col4, #T_234b7_row0_col5, #T_234b7_row1_col0, #T_234b7_row1_col1, #T_234b7_row1_col2, #T_234b7_row1_col3, #T_234b7_row1_col4, #T_234b7_row1_col5, #T_234b7_row2_col0, #T_234b7_row2_col1, #T_234b7_row2_col2, #T_234b7_row2_col3, #T_234b7_row2_col4, #T_234b7_row2_col5, #T_234b7_row3_col0, #T_234b7_row3_col1, #T_234b7_row3_col2, #T_234b7_row3_col3, #T_234b7_row3_col4, #T_234b7_row3_col5, #T_234b7_row4_col0, #T_234b7_row4_col1, #T_234b7_row4_col2, #T_234b7_row4_col3, #T_234b7_row4_col4, #T_234b7_row4_col5, #T_234b7_row5_col0, #T_234b7_row5_col1, #T_234b7_row5_col2, #T_234b7_row5_col3, #T_234b7_row5_col4, #T_234b7_row5_col5, #T_234b7_row6_col0, #T_234b7_row6_col1, #T_234b7_row6_col2, #T_234b7_row6_col3, #T_234b7_row6_col4, #T_234b7_row6_col5, #T_234b7_row7_col0, #T_234b7_row7_col1, #T_234b7_row7_col2, #T_234b7_row7_col3, #T_234b7_row7_col4, #T_234b7_row7_col5, #T_234b7_row8_col0, #T_234b7_row8_col1, #T_234b7_row8_col2, #T_234b7_row8_col3, #T_234b7_row8_col4, #T_234b7_row8_col5, #T_234b7_row9_col0, #T_234b7_row9_col1, #T_234b7_row9_col2, #T_234b7_row9_col3, #T_234b7_row9_col4, #T_234b7_row9_col5, #T_234b7_row10_col0, #T_234b7_row10_col1, #T_234b7_row10_col2, #T_234b7_row10_col3, #T_234b7_row10_col4, #T_234b7_row10_col5, #T_234b7_row11_col0, #T_234b7_row11_col1, #T_234b7_row11_col2, #T_234b7_row11_col3, #T_234b7_row11_col4, #T_234b7_row11_col5, #T_234b7_row12_col0, #T_234b7_row12_col1, #T_234b7_row12_col2, #T_234b7_row12_col3, #T_234b7_row12_col4, #T_234b7_row12_col5, #T_234b7_row13_col0, #T_234b7_row13_col1, #T_234b7_row13_col2, #T_234b7_row13_col3, #T_234b7_row13_col4, #T_234b7_row13_col5, #T_234b7_row14_col0, #T_234b7_row14_col2, #T_234b7_row14_col3, #T_234b7_row14_col4, #T_234b7_row15_col0, #T_234b7_row15_col1, #T_234b7_row15_col2, #T_234b7_row15_col3, #T_234b7_row15_col4, #T_234b7_row15_col5, #T_234b7_row16_col0, #T_234b7_row16_col1, #T_234b7_row16_col2, #T_234b7_row16_col3, #T_234b7_row16_col4, #T_234b7_row16_col5, #T_234b7_row17_col0, #T_234b7_row17_col1, #T_234b7_row17_col2, #T_234b7_row17_col3, #T_234b7_row17_col4, #T_234b7_row17_col5, #T_234b7_row18_col0, #T_234b7_row18_col1, #T_234b7_row18_col2, #T_234b7_row18_col3, #T_234b7_row18_col4, #T_234b7_row18_col5, #T_234b7_row19_col0, #T_234b7_row19_col1, #T_234b7_row19_col2, #T_234b7_row19_col3, #T_234b7_row19_col4, #T_234b7_row19_col5, #T_234b7_row20_col0, #T_234b7_row20_col1, #T_234b7_row20_col2, #T_234b7_row20_col3, #T_234b7_row20_col4, #T_234b7_row20_col5, #T_234b7_row21_col0, #T_234b7_row21_col1, #T_234b7_row21_col2, #T_234b7_row21_col3, #T_234b7_row21_col4, #T_234b7_row21_col5, #T_234b7_row22_col0, #T_234b7_row22_col1, #T_234b7_row22_col2, #T_234b7_row22_col3, #T_234b7_row22_col4, #T_234b7_row22_col5, #T_234b7_row23_col0, #T_234b7_row23_col1, #T_234b7_row23_col2, #T_234b7_row23_col3, #T_234b7_row23_col4, #T_234b7_row23_col5, #T_234b7_row24_col0, #T_234b7_row24_col1, #T_234b7_row24_col2, #T_234b7_row24_col3, #T_234b7_row24_col4, #T_234b7_row24_col5, #T_234b7_row25_col0, #T_234b7_row25_col1, #T_234b7_row25_col2, #T_234b7_row25_col3, #T_234b7_row25_col4, #T_234b7_row25_col5, #T_234b7_row26_col0, #T_234b7_row26_col1, #T_234b7_row26_col2, #T_234b7_row26_col3, #T_234b7_row26_col4, #T_234b7_row26_col5, #T_234b7_row27_col0, #T_234b7_row27_col1, #T_234b7_row27_col2, #T_234b7_row27_col4, #T_234b7_row27_col5, #T_234b7_row28_col0, #T_234b7_row28_col1, #T_234b7_row28_col3, #T_234b7_row28_col4, #T_234b7_row28_col5, #T_234b7_row29_col0, #T_234b7_row29_col1, #T_234b7_row29_col2, #T_234b7_row29_col3, #T_234b7_row29_col4, #T_234b7_row29_col5, #T_234b7_row30_col0, #T_234b7_row30_col1, #T_234b7_row30_col2, #T_234b7_row30_col3, #T_234b7_row30_col4, #T_234b7_row30_col5, #T_234b7_row31_col1, #T_234b7_row31_col2, #T_234b7_row31_col3, #T_234b7_row31_col5 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_234b7_row14_col1, #T_234b7_row14_col5, #T_234b7_row27_col3, #T_234b7_row28_col2, #T_234b7_row31_col0, #T_234b7_row31_col4 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# </style>
# <table id="T_234b7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >data</th>
#       <th id="T_234b7_level0_col0" class="col_heading level0 col0" >PPL</th>
#       <th id="T_234b7_level0_col1" class="col_heading level0 col1" >ACC</th>
#       <th id="T_234b7_level0_col2" class="col_heading level0 col2" >BLEU</th>
#       <th id="T_234b7_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_234b7_level0_col4" class="col_heading level0 col4" >AVG_across_metrics</th>
#       <th id="T_234b7_level0_col5" class="col_heading level0 col5" >AVG_across_datasets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_234b7_level0_row0" class="row_heading level0 row0" >dense</th>
#       <td id="T_234b7_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_234b7_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_234b7_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_234b7_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_234b7_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_234b7_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_234b7_level0_row1" class="row_heading level0 row1" >random_sample</th>
#       <td id="T_234b7_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_234b7_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_234b7_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_234b7_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_234b7_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_234b7_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_234b7_level0_row2" class="row_heading level0 row2" >prototype_flatten</th>
#       <td id="T_234b7_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_234b7_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_234b7_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_234b7_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_234b7_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_234b7_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_234b7_level0_row3" class="row_heading level0 row3" >prototype_mean</th>
#       <td id="T_234b7_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_234b7_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_234b7_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_234b7_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_234b7_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_234b7_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_234b7_level0_row4" class="row_heading level0 row4" >most_different_flatten</th>
#       <td id="T_234b7_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_234b7_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_234b7_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_234b7_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_234b7_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_234b7_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_234b7_level0_row5" class="row_heading level0 row5" >most_different_mean</th>
#       <td id="T_234b7_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_234b7_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_234b7_row5_col2" class="da
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# AVG, sparsity 0.5: PPL, ACC, BLEU, F1
# <style type="text/css">
# #T_d8dab th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_d8dab th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_d8dab_row0_col0, #T_d8dab_row0_col1, #T_d8dab_row0_col2, #T_d8dab_row0_col3, #T_d8dab_row0_col4, #T_d8dab_row0_col5, #T_d8dab_row1_col0, #T_d8dab_row1_col1, #T_d8dab_row1_col2, #T_d8dab_row1_col3, #T_d8dab_row1_col4, #T_d8dab_row1_col5, #T_d8dab_row2_col0, #T_d8dab_row2_col2, #T_d8dab_row2_col3, #T_d8dab_row3_col0, #T_d8dab_row3_col1, #T_d8dab_row3_col2, #T_d8dab_row3_col3, #T_d8dab_row3_col4, #T_d8dab_row3_col5, #T_d8dab_row4_col0, #T_d8dab_row4_col1, #T_d8dab_row4_col2, #T_d8dab_row4_col3, #T_d8dab_row4_col4, #T_d8dab_row4_col5, #T_d8dab_row5_col0, #T_d8dab_row5_col1, #T_d8dab_row5_col2, #T_d8dab_row5_col3, #T_d8dab_row5_col4, #T_d8dab_row5_col5, #T_d8dab_row6_col0, #T_d8dab_row6_col1, #T_d8dab_row6_col2, #T_d8dab_row6_col3, #T_d8dab_row6_col4, #T_d8dab_row6_col5, #T_d8dab_row7_col0, #T_d8dab_row7_col1, #T_d8dab_row7_col2, #T_d8dab_row7_col3, #T_d8dab_row7_col4, #T_d8dab_row7_col5, #T_d8dab_row8_col0, #T_d8dab_row8_col1, #T_d8dab_row8_col2, #T_d8dab_row8_col3, #T_d8dab_row8_col4, #T_d8dab_row8_col5, #T_d8dab_row9_col0, #T_d8dab_row9_col1, #T_d8dab_row9_col2, #T_d8dab_row9_col3, #T_d8dab_row9_col4, #T_d8dab_row9_col5, #T_d8dab_row10_col0, #T_d8dab_row10_col1, #T_d8dab_row10_col2, #T_d8dab_row10_col3, #T_d8dab_row10_col4, #T_d8dab_row10_col5, #T_d8dab_row11_col0, #T_d8dab_row11_col1, #T_d8dab_row11_col2, #T_d8dab_row11_col3, #T_d8dab_row11_col4, #T_d8dab_row11_col5, #T_d8dab_row12_col0, #T_d8dab_row12_col1, #T_d8dab_row12_col2, #T_d8dab_row12_col3, #T_d8dab_row12_col4, #T_d8dab_row12_col5, #T_d8dab_row13_col0, #T_d8dab_row13_col1, #T_d8dab_row13_col2, #T_d8dab_row13_col3, #T_d8dab_row13_col4, #T_d8dab_row13_col5, #T_d8dab_row14_col0, #T_d8dab_row14_col1, #T_d8dab_row14_col2, #T_d8dab_row14_col3, #T_d8dab_row14_col4, #T_d8dab_row14_col5, #T_d8dab_row15_col0, #T_d8dab_row15_col1, #T_d8dab_row15_col2, #T_d8dab_row15_col3, #T_d8dab_row15_col4, #T_d8dab_row15_col5, #T_d8dab_row16_col0, #T_d8dab_row16_col1, #T_d8dab_row16_col2, #T_d8dab_row16_col3, #T_d8dab_row16_col4, #T_d8dab_row16_col5, #T_d8dab_row17_col0, #T_d8dab_row17_col1, #T_d8dab_row17_col2, #T_d8dab_row17_col3, #T_d8dab_row17_col4, #T_d8dab_row17_col5, #T_d8dab_row18_col0, #T_d8dab_row18_col1, #T_d8dab_row18_col2, #T_d8dab_row18_col3, #T_d8dab_row18_col4, #T_d8dab_row18_col5, #T_d8dab_row19_col0, #T_d8dab_row19_col1, #T_d8dab_row19_col2, #T_d8dab_row19_col3, #T_d8dab_row19_col4, #T_d8dab_row19_col5, #T_d8dab_row20_col0, #T_d8dab_row20_col1, #T_d8dab_row20_col2, #T_d8dab_row20_col3, #T_d8dab_row20_col4, #T_d8dab_row20_col5, #T_d8dab_row21_col0, #T_d8dab_row21_col1, #T_d8dab_row21_col2, #T_d8dab_row21_col3, #T_d8dab_row21_col4, #T_d8dab_row21_col5, #T_d8dab_row22_col0, #T_d8dab_row22_col1, #T_d8dab_row22_col2, #T_d8dab_row22_col4, #T_d8dab_row22_col5, #T_d8dab_row23_col0, #T_d8dab_row23_col1, #T_d8dab_row23_col2, #T_d8dab_row23_col3, #T_d8dab_row23_col4, #T_d8dab_row23_col5, #T_d8dab_row24_col0, #T_d8dab_row24_col1, #T_d8dab_row24_col2, #T_d8dab_row24_col3, #T_d8dab_row24_col4, #T_d8dab_row24_col5, #T_d8dab_row25_col0, #T_d8dab_row25_col1, #T_d8dab_row25_col2, #T_d8dab_row25_col3, #T_d8dab_row25_col4, #T_d8dab_row25_col5, #T_d8dab_row26_col0, #T_d8dab_row26_col1, #T_d8dab_row26_col2, #T_d8dab_row26_col3, #T_d8dab_row26_col4, #T_d8dab_row26_col5, #T_d8dab_row27_col1, #T_d8dab_row27_col3, #T_d8dab_row27_col4, #T_d8dab_row27_col5, #T_d8dab_row28_col0, #T_d8dab_row28_col1, #T_d8dab_row28_col2, #T_d8dab_row28_col3, #T_d8dab_row28_col4, #T_d8dab_row28_col5, #T_d8dab_row29_col0, #T_d8dab_row29_col1, #T_d8dab_row29_col2, #T_d8dab_row29_col3, #T_d8dab_row29_col4, #T_d8dab_row29_col5, #T_d8dab_row30_col0, #T_d8dab_row30_col1, #T_d8dab_row30_col2, #T_d8dab_row30_col3, #T_d8dab_row30_col4, #T_d8dab_row30_col5, #T_d8dab_row31_col0, #T_d8dab_row31_col1, #T_d8dab_row31_col2, #T_d8dab_row31_col3, #T_d8dab_row31_col4, #T_d8dab_row31_col5 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_d8dab_row2_col1, #T_d8dab_row2_col4, #T_d8dab_row2_col5, #T_d8dab_row22_col3, #T_d8dab_row27_col0, #T_d8dab_row27_col2 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# </style>
# <table id="T_d8dab">
#   <thead>
#     <tr>
#       <th class="index_name level0" >data</th>
#       <th id="T_d8dab_level0_col0" class="col_heading level0 col0" >PPL</th>
#       <th id="T_d8dab_level0_col1" class="col_heading level0 col1" >ACC</th>
#       <th id="T_d8dab_level0_col2" class="col_heading level0 col2" >BLEU</th>
#       <th id="T_d8dab_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_d8dab_level0_col4" class="col_heading level0 col4" >AVG_across_metrics</th>
#       <th id="T_d8dab_level0_col5" class="col_heading level0 col5" >AVG_across_datasets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8dab_level0_row0" class="row_heading level0 row0" >dense</th>
#       <td id="T_d8dab_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_d8dab_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_d8dab_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_d8dab_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d8dab_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_d8dab_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d8dab_level0_row1" class="row_heading level0 row1" >random_sample</th>
#       <td id="T_d8dab_row1_col0" class="data row1 col0" >0.674</td>
#       <td id="T_d8dab_row1_col1" class="data row1 col1" >0.878</td>
#       <td id="T_d8dab_row1_col2" class="data row1 col2" >0.660</td>
#       <td id="T_d8dab_row1_col3" class="data row1 col3" >0.959</td>
#       <td id="T_d8dab_row1_col4" class="data row1 col4" >0.793</td>
#       <td id="T_d8dab_row1_col5" class="data row1 col5" >0.814</td>
#     </tr>
#     <tr>
#       <th id="T_d8dab_level0_row2" class="row_heading level0 row2" >prototype_flatten</th>
#       <td id="T_d8dab_row2_col0" class="data row2 col0" >0.685</td>
#       <td id="T_d8dab_row2_col1" class="data row2 col1" >0.883</td>
#       <td id="T_d8dab_row2_col2" class="data row2 col2" >0.674</td>
#       <td id="T_d8dab_row2_col3" class="data row2 col3" >0.966</td>
#       <td id="T_d8dab_row2_col4" class="data row2 col4" >0.802</td>
#       <td id="T_d8dab_row2_col5" class="data row2 col5" >0.821</td>
#     </tr>
#     <tr>
#       <th id="T_d8dab_level0_row3" class="row_heading level0 row3" >prototype_mean</th>
#       <td id="T_d8dab_row3_col0" class="data row3 col0" >0.675</td>
#       <td id="T_d8dab_row3_col1" class="data row3 col1" >0.875</td>
#       <td id="T_d8dab_row3_col2" class="data row3 col2" >0.653</td>
#       <td id="T_d8dab_row3_col3" class="data row3 col3" >0.952</td>
#       <td id="T_d8dab_row3_col4" class="data row3 col4" >0.789</td>
#       <td id="T_d8dab_row3_col5" class="data row3 col5" >0.810</td>
#     </tr>
#     <tr>
#       <th id="T_d8dab_level0_row4" class="row_heading level0 row4" >most_different_flatten</th>
#       <td id="T_d8dab_row4_col0" class="data row4 col0" >0.672</td>
#       <td id="T_d8dab_row4_col1" class="data row4 col1" >0.870</td>
#       <td id="T_d8dab_row4_col2" class="data row4 col2" >0.657</td>
#       <td id="T_d8dab_row4_col3" class="data row4 col3" >0.945</td>
#       <td id="T_d8dab_row4_col4" class="data row4 col4" >0.786</td>
#       <td id="T_d8dab_row4_col5" class="data row4 col5" >0.807</td>
#     </tr>
#     <tr>
#       <th id="T_d8dab_level0_row5" class="row_heading level0 row5" >most_different_mean</th>
#       <td id="T_d8dab_row5_col0" class="data row5 col0" >0.671</td>
#       <td id="T_d8dab_row5_col1" class="data row5 col1" >0
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# AVG, sparsity 0.5: PPL, ACC, BLEU, F1
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# <style type="text/css">
# #T_e32a8 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_e32a8 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_e32a8_row0_col0, #T_e32a8_row0_col1, #T_e32a8_row0_col2, #T_e32a8_row0_col3, #T_e32a8_row0_col4, #T_e32a8_row0_col5, #T_e32a8_row1_col0, #T_e32a8_row1_col1, #T_e32a8_row1_col2, #T_e32a8_row1_col3, #T_e32a8_row1_col4, #T_e32a8_row1_col5, #T_e32a8_row3_col0, #T_e32a8_row3_col1, #T_e32a8_row3_col2, #T_e32a8_row3_col3, #T_e32a8_row3_col4, #T_e32a8_row3_col5, #T_e32a8_row4_col0, #T_e32a8_row4_col1, #T_e32a8_row4_col2, #T_e32a8_row4_col3, #T_e32a8_row4_col4, #T_e32a8_row4_col5, #T_e32a8_row5_col0, #T_e32a8_row5_col1, #T_e32a8_row5_col2, #T_e32a8_row5_col3, #T_e32a8_row5_col4, #T_e32a8_row5_col5, #T_e32a8_row6_col0, #T_e32a8_row6_col1, #T_e32a8_row6_col2, #T_e32a8_row6_col3, #T_e32a8_row6_col4, #T_e32a8_row6_col5, #T_e32a8_row7_col0, #T_e32a8_row7_col1, #T_e32a8_row7_col2, #T_e32a8_row7_col3, #T_e32a8_row7_col4, #T_e32a8_row7_col5, #T_e32a8_row8_col0, #T_e32a8_row8_col1, #T_e32a8_row8_col2, #T_e32a8_row8_col3, #T_e32a8_row8_col4, #T_e32a8_row8_col5, #T_e32a8_row9_col0, #T_e32a8_row9_col1, #T_e32a8_row9_col2, #T_e32a8_row9_col3, #T_e32a8_row9_col4, #T_e32a8_row9_col5, #T_e32a8_row10_col0, #T_e32a8_row10_col1, #T_e32a8_row10_col2, #T_e32a8_row10_col3, #T_e32a8_row10_col4, #T_e32a8_row10_col5, #T_e32a8_row11_col0, #T_e32a8_row11_col1, #T_e32a8_row11_col2, #T_e32a8_row11_col3, #T_e32a8_row11_col4, #T_e32a8_row11_col5, #T_e32a8_row12_col0, #T_e32a8_row12_col1, #T_e32a8_row12_col2, #T_e32a8_row12_col3, #T_e32a8_row12_col4, #T_e32a8_row12_col5, #T_e32a8_row13_col0, #T_e32a8_row13_col1, #T_e32a8_row13_col2, #T_e32a8_row13_col3, #T_e32a8_row13_col4, #T_e32a8_row13_col5, #T_e32a8_row14_col0, #T_e32a8_row14_col1, #T_e32a8_row14_col2, #T_e32a8_row14_col3, #T_e32a8_row14_col4, #T_e32a8_row14_col5, #T_e32a8_row15_col0, #T_e32a8_row15_col1, #T_e32a8_row15_col2, #T_e32a8_row15_col3, #T_e32a8_row15_col4, #T_e32a8_row15_col5, #T_e32a8_row16_col0, #T_e32a8_row16_col1, #T_e32a8_row16_col2, #T_e32a8_row16_col3, #T_e32a8_row16_col4, #T_e32a8_row16_col5, #T_e32a8_row17_col0, #T_e32a8_row17_col1, #T_e32a8_row17_col2, #T_e32a8_row17_col3, #T_e32a8_row17_col4, #T_e32a8_row17_col5, #T_e32a8_row18_col0, #T_e32a8_row18_col1, #T_e32a8_row18_col2, #T_e32a8_row18_col3, #T_e32a8_row18_col4, #T_e32a8_row18_col5, #T_e32a8_row19_col0, #T_e32a8_row19_col1, #T_e32a8_row19_col2, #T_e32a8_row19_col3, #T_e32a8_row19_col4, #T_e32a8_row19_col5, #T_e32a8_row20_col0, #T_e32a8_row20_col1, #T_e32a8_row20_col2, #T_e32a8_row20_col3, #T_e32a8_row20_col4, #T_e32a8_row20_col5, #T_e32a8_row21_col0, #T_e32a8_row21_col1, #T_e32a8_row21_col2, #T_e32a8_row21_col3, #T_e32a8_row21_col4, #T_e32a8_row21_col5, #T_e32a8_row22_col0, #T_e32a8_row22_col1, #T_e32a8_row22_col2, #T_e32a8_row22_col3, #T_e32a8_row22_col4, #T_e32a8_row22_col5, #T_e32a8_row23_col0, #T_e32a8_row23_col1, #T_e32a8_row23_col2, #T_e32a8_row23_col3, #T_e32a8_row23_col4, #T_e32a8_row23_col5, #T_e32a8_row24_col0, #T_e32a8_row24_col1, #T_e32a8_row24_col2, #T_e32a8_row24_col3, #T_e32a8_row24_col4, #T_e32a8_row24_col5, #T_e32a8_row25_col0, #T_e32a8_row25_col1, #T_e32a8_row25_col2, #T_e32a8_row25_col3, #T_e32a8_row25_col4, #T_e32a8_row25_col5, #T_e32a8_row26_col0, #T_e32a8_row26_col1, #T_e32a8_row26_col2, #T_e32a8_row26_col3, #T_e32a8_row26_col4, #T_e32a8_row26_col5, #T_e32a8_row27_col0, #T_e32a8_row27_col1, #T_e32a8_row27_col2, #T_e32a8_row27_col3, #T_e32a8_row27_col4, #T_e32a8_row27_col5, #T_e32a8_row28_col0, #T_e32a8_row28_col1, #T_e32a8_row28_col2, #T_e32a8_row28_col3, #T_e32a8_row28_col4, #T_e32a8_row28_col5, #T_e32a8_row29_col0, #T_e32a8_row29_col1, #T_e32a8_row29_col2, #T_e32a8_row29_col3, #T_e32a8_row29_col4, #T_e32a8_row29_col5, #T_e32a8_row30_col0, #T_e32a8_row30_col1, #T_e32a8_row30_col2, #T_e32a8_row30_col3, #T_e32a8_row30_col4, #T_e32a8_row30_col5, #T_e32a8_row31_col0, #T_e32a8_row31_col1, #T_e32a8_row31_col2, #T_e32a8_row31_col3, #T_e32a8_row31_col4, #T_e32a8_row31_col5 {
#   background-color: #ECE3FF;
#   color: black;
# }
# #T_e32a8_row2_col0, #T_e32a8_row2_col1, #T_e32a8_row2_col2, #T_e32a8_row2_col3, #T_e32a8_row2_col4, #T_e32a8_row2_col5 {
#   background-color: #ECE3FF;
#   color: black;
#   background-color: red;
# }
# </style>
# <table id="T_e32a8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >data</th>
#       <th id="T_e32a8_level0_col0" class="col_heading level0 col0" >PPL</th>
#       <th id="T_e32a8_level0_col1" class="col_heading level0 col1" >ACC</th>
#       <th id="T_e32a8_level0_col2" class="col_heading level0 col2" >BLEU</th>
#       <th id="T_e32a8_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_e32a8_level0_col4" class="col_heading level0 col4" >AVG_across_metrics</th>
#       <th id="T_e32a8_level0_col5" class="col_heading level0 col5" >AVG_across_datasets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pruning_data</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e32a8_level0_row0" class="row_heading level0 row0" >dense</th>
#       <td id="T_e32a8_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_e32a8_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_e32a8_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_e32a8_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_e32a8_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_e32a8_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e32a8_level0_row1" class="row_heading level0 row1" >random_sample</th>
#       <td id="T_e32a8_row1_col0" class="data row1 col0" >0.674</td>
#       <td id="T_e32a8_row1_col1" class="data row1 col1" >0.878</td>
#       <td id="T_e32a8_row1_col2" class="data row1 col2" >0.660</td>
#       <td id="T_e32a8_row1_col3" class="data row1 col3" >0.959</td>
#       <td id="T_e32a8_row1_col4" class="data row1 col4" >0.793</td>
#       <td id="T_e32a8_row1_col5" class="data row1 col5" >0.814</td>
#     </tr>
#     <tr>
#       <th id="T_e32a8_level0_row2" class="row_heading level0 row2" >prototype_flatten</th>
#       <td id="T_e32a8_row2_col0" class="data row2 col0" >0.685</td>
#       <td id="T_e32a8_row2_col1" class="data row2 col1" >0.883</td>
#       <td id="T_e32a8_row2_col2" class="data row2 col2" >0.674</td>
#       <td id="T_e32a8_row2_col3" class="data row2 col3" >0.966</td>
#       <td id="T_e32a8_row2_col4" class="data row2 col4" >0.802</td>
#       <td id="T_e32a8_row2_col5" class="data row2 col5" >0.821</td>
#     </tr>
#     <tr>
#       <th id="T_e32a8_level0_row3" class="row_heading level0 row3" >prototype_mean</th>
#       <td id="T_e32a8_row3_col0" class="data row3 col0" >0.675</td>
#       <td id="T_e32a8_row3_col1" class="data row3 col1" >0.875</td>
#       <td id="T_e32a8_row3_col2" class="data row3 col2" >0.653</td>
#       <td id="T_e32a8_row3_col3" class="data row3 col3" >0.952</td>
#       <td id="T_e32a8_row3_col4" class="data row3 col4" >0.789</td>
#       <td id="T_e32a8_row3_col5" class="data row3 col5" >0.810</td>
#     </tr>
#     <tr>
#       <th id="T_e32a8_level0_row4" class="row_heading level0 row4" >most_different_flatten</th>
#       <td id="T_e32a8_row4_col0" class="data row4 col0" >0.672</td>
#       <td id="T_e32a8_row4_col1" class="data row4 col1" >0.870</td>
#       <td id="T_e32a8_row4_col2" class="data row4 col2" >0.657</td>
#       <td id="T_e32a8_row4_col3" class="data row4 col3" >0.945</td>
#       <td id="T_e32a8_row4_col4" class="data row4 col4" >0.786</td>
#       <td id="T_e32a8_row4_col5" class="data row4 col5" >0.807</td>
#     </tr>
#     <tr>
#       <th id="T_e32a8_level0_row5" class="row_heading level0 row5" >most_different_mean</th>
#       <td id="T_e32a8_row5_col0" class="data row5 col0" >0.671</td>
#       <td id="T_e32a8_row5_col1" class="data row5 col1" >0
#       pruning_data  data percentage
# 0             ANLI   ACC   0.617791
# 1             ANLI  BLEU   0.500272
# 2             ANLI    F1   0.800157
# 3             ANLI   PPL   0.523306
# 4            BoolQ   ACC   0.616562
# ..             ...   ...        ...
# 101         random   ACC   0.551822
# 102  random_sample   ACC   0.878425
# 103  random_sample  BLEU   0.659861
# 104  random_sample    F1     0.9588
# 105  random_sample   PPL   0.673528
#
# [106 rows x 3 columns]

# %%
def create_plot_avg_calib(data):
    
    pivot_table = (
    pd.pivot_table(
        data = data.round(precision),
        index='pruning_data',
        values=['PPL', 'ACC', 'BLEU', 'F1', 'MEAN']
        ).reindex(order_columns_with_mean, axis=0).reindex(
            ['PPL', 'ACC', 'BLEU', 'F1', 'MEAN'], axis=1)
    )
    #pivot_table = pivot_table.T
    
    
    pivot_table_style = (
    pivot_table
        .style
            .set_table_styles([headers,index_style])
            .set_properties(**{'background-color': '#ECE3FF','color': 'black'})
            .highlight_max(axis=0, color="red")
            #.highlight_max(pivot_table.index[1:], axis=0, color="yellow")
            .format(precision=precision)
    )
    
    return pivot_table_style


def get_avg_across_model_grouped_by_pruning_dataset_with_mean(results_leave_calibration_out, sparsity=0):
    avg_results_across_metrics = pd.DataFrame()

    for model in results_leave_calibration_out['model'].unique():
        data_this_model = results_leave_calibration_out[results_leave_calibration_out['model'] == model]
        data_this_model = data_this_model[~data_this_model['pruning_data'].str.contains('_no_')]
        
        data_ppl = get_percentage_values(data_this_model[data_this_model['metric'] == 'ppl'], 'ppl')
        data_acc = get_percentage_values(data_this_model[data_this_model['metric'] == 'acc'], 'acc')
        data_bleu = get_percentage_values(data_this_model[data_this_model['metric'] == 'bleu'], 'bleu')
        data_f1 = get_percentage_values(data_this_model[data_this_model['metric'] == 'f1'], 'f1')
        
        
        data_ppl = data_ppl.groupby(['pruning_data']).agg({'percentage': 'mean'}).reset_index()
        data_acc = data_acc.groupby(['pruning_data']).agg({'percentage': 'mean'}).reset_index() 
        data_bleu = data_bleu.groupby(['pruning_data']).agg({'percentage': 'mean'}).reset_index() 
        data_f1 = data_f1.groupby(['pruning_data']).agg({'percentage': 'mean'}).reset_index() 
        
        avg_results_across_metrics = pd.concat([avg_results_across_metrics, data_ppl, data_acc, data_bleu, data_f1])

    all_mean_scores = avg_results_across_metrics.groupby(['pruning_data']).agg(MEAN=('percentage', 'mean'))
    mean_ppl, mean_acc, mean_bleu, mean_f1 = get_avg_across_model_grouped_by_pruning_dataset(results_leave_calibration_out, sparsity)

    all_data = pd.concat([mean_ppl, mean_acc, mean_bleu, mean_f1, all_mean_scores], axis=1).reset_index()
    all_data.columns = ['pruning_data', 'PPL', 'ACC', 'BLEU', 'F1', 'MEAN']

    table = create_plot_avg_calib(all_data)

    print("AVG, sparsity " + str(sparsity) + ": PPL, ACC, BLEU, F1")
    display(table)
    
for sparsity in sparsity_list:
    data_avg_sparsity = results_leave_calibration_out[(results_leave_calibration_out['sparsity'] == sparsity) | (results_leave_calibration_out['sparsity'] == 0.0)]
    get_avg_across_model_grouped_by_pruning_dataset_with_mean(data_avg_sparsity, sparsity)


print("\n\n\n\n")
print("*"*100)
get_avg_across_model_grouped_by_pruning_dataset_with_mean(results_leave_calibration_out, 0.0)
# Out:
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ppl['data'] = 'PPL'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_acc['data'] = 'ACC'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bleu['data'] = 'BLEU'
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_8161/4006852918.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_f1['data'] = 'F1'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 60
#      58 for sparsity in sparsity_list:
#      59     data_avg_sparsity = results_leave_calibration_out[(results_leave_calibration_out['sparsity'] == sparsity) | (results_leave_calibration_out['sparsity'] == 0.0)]
# ---> 60     get_avg_across_model_grouped_by_pruning_dataset_with_mean(data_avg_sparsity, sparsity)
#      63 print("\n\n\n\n")
#      64 print("*"*100)
#
# Cell In[15], line 48, in get_avg_across_model_grouped_by_pruning_dataset_with_mean(results_leave_calibration_out, sparsity)
#      45     avg_results_across_metrics = pd.concat([avg_results_across_metrics, data_ppl, data_acc, data_bleu, data_f1])
#      47 all_mean_scores = avg_results_across_metrics.groupby(['pruning_data']).agg(MEAN=('percentage', 'mean'))
# ---> 48 mean_ppl, mean_acc, mean_bleu, mean_f1 = get_avg_across_model_grouped_by_pruning_dataset(results_leave_calibration_out, sparsity)
#      50 all_data = pd.concat([mean_ppl, mean_acc, mean_bleu, mean_f1, all_mean_scores], axis=1).reset_index()
#      51 all_data.columns = ['pruning_data', 'PPL', 'ACC', 'BLEU', 'F1', 'MEAN']
#
# Cell In[14], line 65, in get_avg_across_model_grouped_by_pruning_dataset(results_leave_calibration_out, sparsity)
#      62 mean = avg_results.groupby(['pruning_data', 'data']).agg({'percentage': 'mean'}).reset_index()
#      64 final_results = pd.concat([mean, mean_across_tasks, mean_across_dataset], axis=0)
# ---> 65 table = create_plot_avg_calib(final_results)
#      67 print("AVG, sparsity " + str(sparsity) + ": PPL, ACC, BLEU, F1")
#      68 display(table)
#
# Cell In[15], line 4, in create_plot_avg_calib(data)
#       1 def create_plot_avg_calib(data):
#       3     pivot_table = (
# ----> 4     pd.pivot_table(
#       5         data = data.round(precision),
#       6         index='pruning_data',
#       7         values=['PPL', 'ACC', 'BLEU', 'F1', 'MEAN']
#       8         ).reindex(order_columns_with_mean, axis=0).reindex(
#       9             ['PPL', 'ACC', 'BLEU', 'F1', 'MEAN'], axis=1)
#      10     )
#      11     #pivot_table = pivot_table.T
#      14     pivot_table_style = (
#      15     pivot_table
#      16         .style
#    (...)
#      21             .format(precision=precision)
#      22     )
#
# File ~/anaconda3/envs/atimolo/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~/anaconda3/envs/atimolo/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'PPL'
